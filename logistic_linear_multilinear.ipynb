# %% [markdown]
# <a href="https://colab.research.google.com/github/ganashreecs22/ml_lab/blob/main/logistic_linear_multilinear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#linear regression
import csv

# Load data from CSV
def load_data(filename):
    X = []
    Y = []
    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            X.append(float(row['YearsExperience']))
            Y.append(float(row['Salary']))
    return X, Y

# Mean
def mean(values):
    return sum(values) / len(values)

# Variance
def variance(values, mean_val):
    return sum((x - mean_val) ** 2 for x in values)

# Covariance
def covariance(X, mean_x, Y, mean_y):
    return sum((X[i] - mean_x) * (Y[i] - mean_y) for i in range(len(X)))

# Coefficients (slope and intercept)
def coefficients(X, Y):
    mean_x = mean(X)
    mean_y = mean(Y)
    covar = covariance(X, mean_x, Y, mean_y)
    var_x = variance(X, mean_x)
    m = covar / var_x
    b = mean_y - m * mean_x
    return m, b

# Predict
def predict(X, m, b):
    return [m * x + b for x in X]

# Mean Squared Error
def mean_squared_error(actual, predicted):
    return sum((a - p) ** 2 for a, p in zip(actual, predicted)) / len(actual)

# --- MAIN EXECUTION ---

# Load data
X, Y = load_data("/content/Salary_Data.csv")

# Train model
m, b = coefficients(X, Y)
print(f"Learned model: Salary = {m:.2f} * YearsExperience + {b:.2f}")

# Make predictions
predictions = predict(X, m, b)

# Evaluate
mse = mean_squared_error(Y, predictions)
print(f"Mean Squared Error: {mse:.2f}")

# Display predictions
for i in range(len(X)):
    print(f"Years: {X[i]}, Actual Salary: {Y[i]}, Predicted: {predictions[i]:.2f}")
# Out:
# Learned model: Salary = 9449.96 * YearsExperience + 25792.20
# Mean Squared Error: 31270951.72
# Years: 1.1, Actual Salary: 39343.0, Predicted: 36187.16
# Years: 1.3, Actual Salary: 46205.0, Predicted: 38077.15
# Years: 1.5, Actual Salary: 37731.0, Predicted: 39967.14
# Years: 2.0, Actual Salary: 43525.0, Predicted: 44692.12
# Years: 2.2, Actual Salary: 39891.0, Predicted: 46582.12
# Years: 2.9, Actual Salary: 56642.0, Predicted: 53197.09
# Years: 3.0, Actual Salary: 60150.0, Predicted: 54142.09
# Years: 3.2, Actual Salary: 54445.0, Predicted: 56032.08
# Years: 3.2, Actual Salary: 64445.0, Predicted: 56032.08
# Years: 3.7, Actual Salary: 57189.0, Predicted: 60757.06
# Years: 3.9, Actual Salary: 63218.0, Predicted: 62647.05
# Years: 4.0, Actual Salary: 55794.0, Predicted: 63592.05
# Years: 4.0, Actual Salary: 56957.0, Predicted: 63592.05
# Years: 4.1, Actual Salary: 57081.0, Predicted: 64537.05
# Years: 4.5, Actual Salary: 61111.0, Predicted: 68317.03
# Years: 4.9, Actual Salary: 67938.0, Predicted: 72097.02
# Years: 5.1, Actual Salary: 66029.0, Predicted: 73987.01
# Years: 5.3, Actual Salary: 83088.0, Predicted: 75877.00
# Years: 5.9, Actual Salary: 81363.0, Predicted: 81546.98
# Years: 6.0, Actual Salary: 93940.0, Predicted: 82491.97
# Years: 6.8, Actual Salary: 91738.0, Predicted: 90051.94
# Years: 7.1, Actual Salary: 98273.0, Predicted: 92886.93
# Years: 7.9, Actual Salary: 101302.0, Predicted: 100446.90
# Years: 8.2, Actual Salary: 113812.0, Predicted: 103281.89
# Years: 8.7, Actual Salary: 109431.0, Predicted: 108006.87
# Years: 9.0, Actual Salary: 105582.0, Predicted: 110841.86
# Years: 9.5, Actual Salary: 116969.0, Predicted: 115566.84
# Years: 9.6, Actual Salary: 112635.0, Predicted: 116511.84
# Years: 10.3, Actual Salary: 122391.0, Predicted: 123126.81
# Years: 10.5, Actual Salary: 121872.0, Predicted: 125016.80

# %%
# Multiple Linear Regression from Scratch with Categorical Handling

def load_csv(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()
        headers = lines[0].strip().split(',')
        data = []
        for line in lines[1:]:
            values = line.strip().split(',')
            row = []
            for value in values:
                # Convert categorical Yes/No to 1/0
                if value.lower() == 'yes':
                    row.append(1.0)
                elif value.lower() == 'no':
                    row.append(0.0)
                else:
                    row.append(float(value))
            data.append(row)
    return headers, data

def mean(values):
    return sum(values) / len(values)

def variance(values, mean_val):
    return sum((x - mean_val) ** 2 for x in values)

def covariance(x, x_mean, y, y_mean):
    return sum((x[i] - x_mean) * (y[i] - y_mean) for i in range(len(x)))

def coefficients(dataset):
    X = [row[:-1] for row in dataset]
    Y = [row[-1] for row in dataset]
    means = [mean(col) for col in zip(*X)]
    y_mean = mean(Y)
    coeffs = []
    for i in range(len(X[0])):
        cov = covariance([row[i] for row in X], means[i], Y, y_mean)
        var = variance([row[i] for row in X], means[i])
        coeffs.append(cov / var if var != 0 else 0)
    intercept = y_mean - sum(coeffs[i] * means[i] for i in range(len(coeffs)))
    return intercept, coeffs

def predict(row, intercept, coeffs):
    return intercept + sum(coeffs[i] * row[i] for i in range(len(coeffs)))

def mean_squared_error(actual, predicted):
    return sum((actual[i] - predicted[i]) ** 2 for i in range(len(actual))) / len(actual)

# MAIN
if __name__ == "__main__":
    headers, data = load_csv("/content/Student_Performance.csv")

    intercept, coeffs = coefficients(data)

    print("Intercept:", intercept)
    print("Coefficients:")
    for i in range(len(coeffs)):
        print(f"{headers[i]}: {coeffs[i]}")

    predictions = [predict(row[:-1], intercept, coeffs) for row in data]
    actual = [row[-1] for row in data]

    mse = mean_squared_error(actual, predictions)
    print("Mean Squared Error:", mse)

    for i in range(len(data)):
        print(f"Actual: {actual[i]}, Predicted: {predictions[i]:.2f}")
# Out:
# Intercept: -34.381635338725914
# Coefficients:
# Hours Studied: 2.7730628246389557
# Previous Scores: 1.0138367015830627
# Extracurricular Activities: 0.9423777675793193
# Sleep Hours: 0.5449945877537364
# Sample Question Papers Practiced: 0.28991782346265094
# Mean Squared Error: 4.31274844054749
# Actual: 91.0, Predicted: 91.54
# Actual: 65.0, Predicted: 62.61
# Actual: 45.0, Predicted: 44.85
# Actual: 36.0, Predicted: 36.45
# Actual: 66.0, Predicted: 66.88
# Actual: 61.0, Predicted: 59.66
# Actual: 63.0, Predicted: 64.45
# Actual: 42.0, Predicted: 38.29
# Actual: 61.0, Predicted: 62.49
# Actual: 69.0, Predicted: 69.12
# Actual: 84.0, Predicted: 83.69
# Actual: 73.0, Predicted: 71.75
# Actual: 27.0, Predicted: 27.07
# Actual: 33.0, Predicted: 32.67
# Actual: 68.0, Predicted: 65.71
# Actual: 43.0, Predicted: 47.21
# Actual: 67.0, Predicted: 68.27
# Actual: 70.0, Predicted: 71.74
# Actual: 30.0, Predicted: 31.64
# Actual: 63.0, Predicted: 59.34
# Actual: 71.0, Predicted: 72.75
# Actual: 85.0, Predicted: 84.49
# Actual: 73.0, Predicted: 72.10
# Actual: 57.0, Predicted: 59.03
# Actual: 35.0, Predicted: 39.92
# Actual: 49.0, Predicted: 53.80
# Actual: 66.0, Predicted: 63.77
# Actual: 83.0, Predicted: 81.69
# Actual: 74.0, Predicted: 74.90
# Actual: 74.0, Predicted: 74.72
# Actual: 39.0, Predicted: 41.41
# Actual: 36.0, Predicted: 35.78
# Actual: 58.0, Predicted: 57.27
# Actual: 47.0, Predicted: 48.89
# Actual: 60.0, Predicted: 59.67
# Actual: 74.0, Predicted: 76.51
# Actual: 42.0, Predicted: 41.76
# Actual: 68.0, Predicted: 68.51
# Actual: 32.0, Predicted: 30.34
# Actual: 64.0, Predicted: 63.11
# Actual: 45.0, Predicted: 47.32
# Actual: 39.0, Predicted: 39.25
# Actual: 58.0, Predicted: 55.48
# Actual: 36.0, Predicted: 38.02
# Actual: 71.0, Predicted: 71.24
# Actual: 54.0, Predicted: 54.98
# Actual: 17.0, Predicted: 16.74
# Actual: 54.0, Predicted: 54.64
# Actual: 58.0, Predicted: 57.28
# Actual: 53.0, Predicted: 54.04
# Actual: 27.0, Predicted: 27.82
# Actual: 65.0, Predicted: 65.90
# Actual: 75.0, Predicted: 71.89
# Actual: 52.0, Predicted: 50.96
# Actual: 78.0, Predicted: 76.23
# Actual: 91.0, Predicted: 86.84
# Actual: 33.0, Predicted: 33.21
# Actual: 47.0, Predicted: 48.12
# Actual: 78.0, Predicted: 79.34
# Actual: 38.0, Predicted: 39.74
# Actual: 70.0, Predicted: 74.63
# Actual: 98.0, Predicted: 95.67
# Actual: 87.0, Predicted: 86.23
# Actual: 49.0, Predicted: 49.16
# Actual: 41.0, Predicted: 41.71
# Actual: 71.0, Predicted: 72.01
# Actual: 54.0, Predicted: 52.84
# Actual: 42.0, Predicted: 42.29
# Actual: 91.0, Predicted: 91.07
# Actual: 61.0, Predicted: 64.22
# Actual: 74.0, Predicted: 76.16
# Actual: 54.0, Predicted: 52.03
# Actual: 81.0, Predicted: 78.83
# Actual: 52.0, Predicted: 54.36
# Actual: 65.0, Predicted: 63.75
# Actual: 36.0, Predicted: 37.02
# Actual: 61.0, Predicted: 61.43
# Actual: 35.0, Predicted: 32.35
# Actual: 15.0, Predicted: 16.57
# Actual: 88.0, Predicted: 88.91
# Actual: 45.0, Predicted: 48.10
# Actual: 49.0, Predicted: 50.47
# Actual: 33.0, Predicted: 34.96
# Actual: 60.0, Predicted: 58.91
# Actual: 71.0, Predicted: 71.37
# Actual: 81.0, Predicted: 78.14
# Actual: 67.0, Predicted: 66.08
# Actual: 95.0, Predicted: 93.42
# Actual: 58.0, Predicted: 56.47
# Actual: 29.0, Predicted: 28.79
# Actual: 21.0, Predicted: 19.20
# Actual: 38.0, Predicted: 37.76
# Actual: 60.0, Predicted: 60.29
# Actual: 76.0, Predicted: 76.63
# Actual: 69.0, Predicted: 70.78
# Actual: 30.0, Predicted: 27.87
# Actual: 57.0, Predicted: 55.70
# Actual: 81.0, Predicted: 84.81
# Actual: 36.0, Predicted: 34.53
# Actual: 25.0, Predicted: 25.08
# Actual: 27.0, Predicted: 28.51
# Actual: 61.0, Predicted: 58.04
# Actual: 34.0, Predicted: 31.20
# Actual: 76.0, Predicted: 74.64
# Actual: 57.0, Predicted: 56.55
# Actual: 45.0, Predicted: 44.10
# Actual: 76.0, Predicted: 79.69
# Actual: 83.0, Predicted: 82.06
# Actual: 50.0, Predicted: 49.59
# Actual: 81.0, Predicted: 79.91
# Actual: 66.0, Predicted: 65.58
# Actual: 38.0, Predicted: 39.66
# Actual: 56.0, Predicted: 58.70
# Actual: 25.0, Predicted: 24.83
# Actual: 56.0, Predicted: 58.47
# Actual: 82.0, Predicted: 81.72
# Actual: 23.0, Predicted: 25.64
# Actual: 56.0, Predicted: 54.31
# Actual: 46.0, Predicted: 49.09
# Actual: 43.0, Predicted: 43.75
# Actual: 30.0, Predicted: 30.75
# Actual: 92.0, Predicted: 89.15
# Actual: 45.0, Predicted: 43.94
# Actual: 70.0, Predicted: 71.88
# Actual: 36.0, Predicted: 37.69
# Actual: 71.0, Predicted: 67.59
# Actual: 49.0, Predicted: 48.20
# Actual: 82.0, Predicted: 82.37
# Actual: 71.0, Predicted: 72.04
# Actual: 43.0, Predicted: 45.57
# Actual: 77.0, Predicted: 72.57
# Actual: 86.0, Predicted: 85.34
# Actual: 34.0, Predicted: 36.72
# Actual: 49.0, Predicted: 47.58
# Actual: 69.0, Predicted: 68.20
# Actual: 84.0, Predicted: 85.95
# Actual: 41.0, Predicted: 41.36
# Actual: 68.0, Predicted: 67.18
# Actual: 44.0, Predicted: 42.66
# Actual: 41.0, Predicted: 42.39
# Actual: 58.0, Predicted: 62.40
# Actual: 68.0, Predicted: 67.44
# Actual: 94.0, Predicted: 92.10
# Actual: 47.0, Predicted: 47.80
# Actual: 40.0, Predicted: 40.35
# Actual: 100.0, Predicted: 96.72
# Actual: 23.0, Predicted: 27.17
# Actual: 36.0, Predicted: 34.59
# Actual: 47.0, Predicted: 45.20
# Actual: 60.0, Predicted: 61.82
# Actual: 83.0, Predicted: 87.99
# Actual: 33.0, Predicted: 32.81
# Actual: 36.0, Predicted: 35.47
# Actual: 74.0, Predicted: 71.82
# Actual: 42.0, Predicted: 42.79
# Actual: 47.0, Predicted: 47.08
# Actual: 31.0, Predicted: 35.14
# Actual: 26.0, Predicted: 24.42
# Actual: 58.0, Predicted: 61.93
# Actual: 42.0, Predicted: 42.22
# Actual: 18.0, Predicted: 20.78
# Actual: 85.0, Predicted: 83.79
# Actual: 36.0, Predicted: 36.86
# Actual: 58.0, Predicted: 58.07
# Actual: 45.0, Predicted: 46.51
# Actual: 60.0, Predicted: 59.87
# Actual: 56.0, Predicted: 53.17
# Actual: 42.0, Predicted: 41.39
# Actual: 33.0, Predicted: 33.88
# Actual: 77.0, Predicted: 77.32
# Actual: 51.0, Predicted: 48.62
# Actual: 72.0, Predicted: 74.38
# Actual: 57.0, Predicted: 56.37
# Actual: 53.0, Predicted: 56.25
# Actual: 16.0, Predicted: 16.42
# Actual: 45.0, Predicted: 47.34
# Actual: 49.0, Predicted: 49.62
# Actual: 67.0, Predicted: 67.30
# Actual: 49.0, Predicted: 47.25
# Actual: 73.0, Predicted: 74.88
# Actual: 65.0, Predicted: 62.66
# Actual: 27.0, Predicted: 28.97
# Actual: 72.0, Predicted: 70.81
# Actual: 74.0, Predicted: 74.78
# Actual: 38.0, Predicted: 36.77
# Actual: 67.0, Predicted: 67.34
# Actual: 28.0, Predicted: 30.06
# Actual: 73.0, Predicted: 71.05
# Actual: 72.0, Predicted: 70.66
# Actual: 42.0, Predicted: 43.18
# Actual: 47.0, Predicted: 45.97
# Actual: 77.0, Predicted: 77.06
# Actual: 49.0, Predicted: 48.04
# Actual: 30.0, Predicted: 28.39
# Actual: 54.0, Predicted: 56.27
# Actual: 56.0, Predicted: 56.72
# Actual: 75.0, Predicted: 77.43
# Actual: 78.0, Predicted: 80.05
# Actual: 32.0, Predicted: 33.17
# Actual: 89.0, Predicted: 86.48
# Actual: 29.0, Predicted: 30.03
# Actual: 57.0, Predicted: 57.57
# Actual: 48.0, Predicted: 48.63
# Actual: 27.0, Predicted: 26.50
# Actual: 38.0, Predicted: 40.33
# Actual: 18.0, Predicted: 21.79
# Actual: 66.0, Predicted: 63.15
# Actual: 65.0, Predicted: 63.29
# Actual: 27.0, Predicted: 28.32
# Actual: 33.0, Predicted: 35.14
# Actual: 37.0, Predicted: 38.96
# Actual: 29.0, Predicted: 31.66
# Actual: 26.0, Predicted: 26.57
# Actual: 72.0, Predicted: 71.28
# Actual: 77.0, Predicted: 74.59
# Actual: 45.0, Predicted: 44.83
# Actual: 41.0, Predicted: 39.26
# Actual: 73.0, Predicted: 73.27
# Actual: 43.0, Predicted: 43.54
# Actual: 39.0, Predicted: 39.05
# Actual: 54.0, Predicted: 52.62
# Actual: 62.0, Predicted: 63.03
# Actual: 63.0, Predicted: 62.21
# Actual: 59.0, Predicted: 58.42
# Actual: 46.0, Predicted: 45.67
# Actual: 42.0, Predicted: 39.34
# Actual: 30.0, Predicted: 29.11
# Actual: 63.0, Predicted: 64.18
# Actual: 89.0, Predicted: 88.73
# Actual: 62.0, Predicted: 66.31
# Actual: 77.0, Predicted: 76.85
# Actual: 88.0, Predicted: 89.97
# Actual: 35.0, Predicted: 35.53
# Actual: 60.0, Predicted: 60.46
# Actual: 92.0, Predicted: 90.24
# Actual: 38.0, Predicted: 33.77
# Actual: 56.0, Predicted: 53.23
# Actual: 70.0, Predicted: 70.28
# Actual: 35.0, Predicted: 34.00
# Actual: 47.0, Predicted: 47.97
# Actual: 66.0, Predicted: 65.91
# Actual: 43.0, Predicted: 42.64
# Actual: 81.0, Predicted: 82.85
# Actual: 43.0, Predicted: 44.43
# Actual: 46.0, Predicted: 49.62
# Actual: 61.0, Predicted: 61.02
# Actual: 27.0, Predicted: 27.64
# Actual: 77.0, Predicted: 77.15
# Actual: 43.0, Predicted: 44.40
# Actual: 60.0, Predicted: 59.69
# Actual: 48.0, Predicted: 47.41
# Actual: 47.0, Predicted: 46.38
# Actual: 60.0, Predicted: 60.24
# Actual: 53.0, Predicted: 54.51
# Actual: 19.0, Predicted: 18.99
# Actual: 23.0, Predicted: 22.51
# Actual: 81.0, Predicted: 81.95
# Actual: 41.0, Predicted: 42.47
# Actual: 71.0, Predicted: 71.56
# Actual: 75.0, Predicted: 74.89
# Actual: 89.0, Predicted: 87.75
# Actual: 28.0, Predicted: 25.62
# Actual: 60.0, Predicted: 61.02
# Actual: 54.0, Predicted: 49.98
# Actual: 41.0, Predicted: 43.16
# Actual: 52.0, Predicted: 52.92
# Actual: 53.0, Predicted: 51.25
# Actual: 52.0, Predicted: 55.45
# Actual: 47.0, Predicted: 47.28
# Actual: 71.0, Predicted: 71.97
# Actual: 42.0, Predicted: 45.12
# Actual: 21.0, Predicted: 24.28
# Actual: 48.0, Predicted: 46.10
# Actual: 64.0, Predicted: 63.56
# Actual: 38.0, Predicted: 36.89
# Actual: 49.0, Predicted: 51.00
# Actual: 35.0, Predicted: 35.07
# Actual: 73.0, Predicted: 67.68
# Actual: 81.0, Predicted: 81.09
# Actual: 47.0, Predicted: 46.59
# Actual: 36.0, Predicted: 35.71
# Actual: 63.0, Predicted: 62.52
# Actual: 52.0, Predicted: 54.09
# Actual: 58.0, Predicted: 57.95
# Actual: 77.0, Predicted: 74.02
# Actual: 58.0, Predicted: 57.78
# Actual: 33.0, Predicted: 30.38
# Actual: 67.0, Predicted: 61.21
# Actual: 76.0, Predicted: 77.94
# Actual: 62.0, Predicted: 61.66
# Actual: 37.0, Predicted: 39.39
# Actual: 86.0, Predicted: 86.23
# Actual: 37.0, Predicted: 32.35
# Actual: 88.0, Predicted: 85.72
# Actual: 38.0, Predicted: 37.13
# Actual: 76.0, Predicted: 78.83
# Actual: 57.0, Predicted: 57.54
# Actual: 82.0, Predicted: 84.19
# Actual: 35.0, Predicted: 36.68
# Actual: 41.0, Predicted: 39.61
# Actual: 75.0, Predicted: 73.62
# Actual: 51.0, Predicted: 50.53
# Actual: 34.0, Predicted: 35.39
# Actual: 92.0, Predicted: 90.13
# Actual: 39.0, Predicted: 35.20
# Actual: 56.0, Predicted: 53.37
# Actual: 69.0, Predicted: 67.85
# Actual: 69.0, Predicted: 67.40
# Actual: 40.0, Predicted: 38.53
# Actual: 63.0, Predicted: 62.83
# Actual: 86.0, Predicted: 85.11
# Actual: 89.0, Predicted: 89.90
# Actual: 94.0, Predicted: 91.90
# Actual: 79.0, Predicted: 79.48
# Actual: 44.0, Predicted: 45.67
# Actual: 33.0, Predicted: 35.47
# Actual: 36.0, Predicted: 35.83
# Actual: 50.0, Predicted: 51.61
# Actual: 94.0, Predicted: 88.31
# Actual: 22.0, Predicted: 21.36
# Actual: 44.0, Predicted: 45.19
# Actual: 60.0, Predicted: 59.70
# Actual: 64.0, Predicted: 62.61
# Actual: 58.0, Predicted: 57.52
# Actual: 78.0, Predicted: 80.06
# Actual: 51.0, Predicted: 51.61
# Actual: 30.0, Predicted: 30.06
# Actual: 29.0, Predicted: 29.74
# Actual: 22.0, Predicted: 24.16
# Actual: 51.0, Predicted: 49.18
# Actual: 45.0, Predicted: 43.86
# Actual: 70.0, Predicted: 68.64
# Actual: 10.0, Predicted: 14.28
# Actual: 38.0, Predicted: 38.22
# Actual: 30.0, Predicted: 27.36
# Actual: 82.0, Predicted: 81.67
# Actual: 74.0, Predicted: 76.07
# Actual: 87.0, Predicted: 83.83
# Actual: 77.0, Predicted: 81.51
# Actual: 72.0, Predicted: 71.99
# Actual: 51.0, Predicted: 47.27
# Actual: 40.0, Predicted: 42.98
# Actual: 72.0, Predicted: 72.58
# Actual: 68.0, Predicted: 70.87
# Actual: 22.0, Predicted: 20.17
# Actual: 67.0, Predicted: 69.11
# Actual: 18.0, Predicted: 16.86
# Actual: 64.0, Predicted: 61.50
# Actual: 66.0, Predicted: 68.64
# Actual: 50.0, Predicted: 52.46
# Actual: 68.0, Predicted: 66.36
# Actual: 44.0, Predicted: 42.86
# Actual: 90.0, Predicted: 90.08
# Actual: 41.0, Predicted: 40.41
# Actual: 83.0, Predicted: 79.18
# Actual: 57.0, Predicted: 56.90
# Actual: 64.0, Predicted: 61.86
# Actual: 18.0, Predicted: 19.41
# Actual: 62.0, Predicted: 56.68
# Actual: 66.0, Predicted: 67.47
# Actual: 85.0, Predicted: 82.06
# Actual: 62.0, Predicted: 64.45
# Actual: 62.0, Predicted: 61.07
# Actual: 62.0, Predicted: 61.51
# Actual: 26.0, Predicted: 26.24
# Actual: 66.0, Predicted: 64.75
# Actual: 43.0, Predicted: 41.89
# Actual: 30.0, Predicted: 29.75
# Actual: 25.0, Predicted: 28.88
# Actual: 77.0, Predicted: 74.11
# Actual: 88.0, Predicted: 84.63
# Actual: 62.0, Predicted: 61.92
# Actual: 82.0, Predicted: 81.49
# Actual: 73.0, Predicted: 70.41
# Actual: 44.0, Predicted: 42.34
# Actual: 40.0, Predicted: 40.51
# Actual: 39.0, Predicted: 41.41
# Actual: 34.0, Predicted: 31.93
# Actual: 27.0, Predicted: 26.51
# Actual: 73.0, Predicted: 73.62
# Actual: 46.0, Predicted: 47.68
# Actual: 78.0, Predicted: 78.43
# Actual: 80.0, Predicted: 78.76
# Actual: 33.0, Predicted: 33.37
# Actual: 68.0, Predicted: 68.08
# Actual: 45.0, Predicted: 45.23
# Actual: 56.0, Predicted: 55.01
# Actual: 58.0, Predicted: 60.92
# Actual: 37.0, Predicted: 37.70
# Actual: 88.0, Predicted: 90.15
# Actual: 75.0, Predicted: 74.69
# Actual: 70.0, Predicted: 71.30
# Actual: 62.0, Predicted: 59.76
# Actual: 57.0, Predicted: 57.24
# Actual: 32.0, Predicted: 33.82
# Actual: 53.0, Predicted: 55.49
# Actual: 82.0, Predicted: 81.19
# Actual: 41.0, Predicted: 44.30
# Actual: 75.0, Predicted: 75.06
# Actual: 63.0, Predicted: 63.97
# Actual: 17.0, Predicted: 18.63
# Actual: 24.0, Predicted: 23.70
# Actual: 69.0, Predicted: 70.56
# Actual: 47.0, Predicted: 47.07
# Actual: 43.0, Predicted: 44.34
# Actual: 48.0, Predicted: 49.87
# Actual: 17.0, Predicted: 17.43
# Actual: 75.0, Predicted: 72.62
# Actual: 54.0, Predicted: 48.92
# Actual: 59.0, Predicted: 59.73
# Actual: 56.0, Predicted: 54.86
# Actual: 20.0, Predicted: 20.91
# Actual: 34.0, Predicted: 32.77
# Actual: 54.0, Predicted: 50.74
# Actual: 83.0, Predicted: 82.51
# Actual: 59.0, Predicted: 56.85
# Actual: 63.0, Predicted: 61.79
# Actual: 72.0, Predicted: 71.59
# Actual: 70.0, Predicted: 70.42
# Actual: 41.0, Predicted: 42.05
# Actual: 54.0, Predicted: 56.04
# Actual: 21.0, Predicted: 19.30
# Actual: 83.0, Predicted: 79.17
# Actual: 64.0, Predicted: 66.99
# Actual: 51.0, Predicted: 49.72
# Actual: 66.0, Predicted: 66.32
# Actual: 83.0, Predicted: 84.59
# Actual: 26.0, Predicted: 24.88
# Actual: 49.0, Predicted: 50.61
# Actual: 85.0, Predicted: 84.62
# Actual: 95.0, Predicted: 95.79
# Actual: 56.0, Predicted: 57.27
# Actual: 50.0, Predicted: 48.39
# Actual: 23.0, Predicted: 27.14
# Actual: 26.0, Predicted: 27.09
# Actual: 30.0, Predicted: 34.00
# Actual: 28.0, Predicted: 27.71
# Actual: 48.0, Predicted: 48.59
# Actual: 46.0, Predicted: 46.91
# Actual: 73.0, Predicted: 72.13
# Actual: 45.0, Predicted: 44.17
# Actual: 76.0, Predicted: 74.03
# Actual: 71.0, Predicted: 64.41
# Actual: 60.0, Predicted: 61.19
# Actual: 77.0, Predicted: 78.22
# Actual: 36.0, Predicted: 36.27
# Actual: 96.0, Predicted: 95.23
# Actual: 62.0, Predicted: 58.53
# Actual: 22.0, Predicted: 21.53
# Actual: 21.0, Predicted: 22.93
# Actual: 79.0, Predicted: 80.75
# Actual: 82.0, Predicted: 80.21
# Actual: 55.0, Predicted: 55.96
# Actual: 22.0, Predicted: 19.02
# Actual: 70.0, Predicted: 69.16
# Actual: 37.0, Predicted: 38.20
# Actual: 42.0, Predicted: 44.49
# Actual: 64.0, Predicted: 62.50
# Actual: 72.0, Predicted: 72.30
# Actual: 42.0, Predicted: 39.76
# Actual: 56.0, Predicted: 54.80
# Actual: 43.0, Predicted: 42.31
# Actual: 24.0, Predicted: 25.91
# Actual: 55.0, Predicted: 56.40
# Actual: 64.0, Predicted: 63.70
# Actual: 34.0, Predicted: 37.92
# Actual: 78.0, Predicted: 76.90
# Actual: 71.0, Predicted: 68.87
# Actual: 33.0, Predicted: 34.18
# Actual: 46.0, Predicted: 43.96
# Actual: 86.0, Predicted: 83.64
# Actual: 34.0, Predicted: 33.31
# Actual: 26.0, Predicted: 27.11
# Actual: 44.0, Predicted: 42.15
# Actual: 53.0, Predicted: 55.43
# Actual: 61.0, Predicted: 60.96
# Actual: 84.0, Predicted: 85.09
# Actual: 40.0, Predicted: 41.86
# Actual: 53.0, Predicted: 51.82
# Actual: 67.0, Predicted: 68.59
# Actual: 58.0, Predicted: 60.73
# Actual: 41.0, Predicted: 36.16
# Actual: 89.0, Predicted: 90.25
# Actual: 85.0, Predicted: 86.87
# Actual: 33.0, Predicted: 31.51
# Actual: 20.0, Predicted: 21.15
# Actual: 66.0, Predicted: 69.05
# Actual: 38.0, Predicted: 40.37
# Actual: 25.0, Predicted: 25.93
# Actual: 43.0, Predicted: 44.96
# Actual: 79.0, Predicted: 80.87
# Actual: 16.0, Predicted: 17.90
# Actual: 67.0, Predicted: 64.36
# Actual: 80.0, Predicted: 75.32
# Actual: 26.0, Predicted: 24.46
# Actual: 57.0, Predicted: 56.77
# Actual: 91.0, Predicted: 93.24
# Actual: 29.0, Predicted: 27.92
# Actual: 48.0, Predicted: 50.34
# Actual: 84.0, Predicted: 84.96
# Actual: 33.0, Predicted: 30.07
# Actual: 82.0, Predicted: 77.64
# Actual: 81.0, Predicted: 80.86
# Actual: 24.0, Predicted: 21.67
# Actual: 81.0, Predicted: 78.21
# Actual: 54.0, Predicted: 53.11
# Actual: 25.0, Predicted: 26.54
# Actual: 53.0, Predicted: 54.21
# Actual: 48.0, Predicted: 47.56
# Actual: 40.0, Predicted: 42.84
# Actual: 66.0, Predicted: 67.17
# Actual: 29.0, Predicted: 28.88
# Actual: 73.0, Predicted: 73.95
# Actual: 89.0, Predicted: 85.75
# Actual: 27.0, Predicted: 26.92
# Actual: 40.0, Predicted: 38.46
# Actual: 83.0, Predicted: 82.94
# Actual: 69.0, Predicted: 68.45
# Actual: 72.0, Predicted: 74.09
# Actual: 77.0, Predicted: 75.96
# Actual: 32.0, Predicted: 30.79
# Actual: 49.0, Predicted: 45.98
# Actual: 44.0, Predicted: 48.39
# Actual: 57.0, Predicted: 58.10
# Actual: 34.0, Predicted: 37.25
# Actual: 76.0, Predicted: 77.93
# Actual: 22.0, Predicted: 21.89
# Actual: 30.0, Predicted: 29.14
# Actual: 67.0, Predicted: 61.99
# Actual: 71.0, Predicted: 68.04
# Actual: 29.0, Predicted: 30.96
# Actual: 74.0, Predicted: 72.64
# Actual: 67.0, Predicted: 64.75
# Actual: 46.0, Predicted: 46.80
# Actual: 34.0, Predicted: 34.17
# Actual: 76.0, Predicted: 76.88
# Actual: 64.0, Predicted: 62.79
# Actual: 46.0, Predicted: 45.98
# Actual: 68.0, Predicted: 67.57
# Actual: 58.0, Predicted: 53.81
# Actual: 41.0, Predicted: 38.80
# Actual: 64.0, Predicted: 66.74
# Actual: 84.0, Predicted: 86.88
# Actual: 70.0, Predicted: 69.01
# Actual: 77.0, Predicted: 76.93
# Actual: 60.0, Predicted: 63.08
# Actual: 65.0, Predicted: 68.42
# Actual: 21.0, Predicted: 21.84
# Actual: 60.0, Predicted: 59.99
# Actual: 48.0, Predicted: 46.93
# Actual: 77.0, Predicted: 77.82
# Actual: 63.0, Predicted: 64.25
# Actual: 68.0, Predicted: 69.21
# Actual: 81.0, Predicted: 79.84
# Actual: 29.0, Predicted: 31.55
# Actual: 66.0, Predicted: 66.03
# Actual: 36.0, Predicted: 34.66
# Actual: 29.0, Predicted: 29.93
# Actual: 32.0, Predicted: 31.18
# Actual: 31.0, Predicted: 30.46
# Actual: 45.0, Predicted: 46.55
# Actual: 65.0, Predicted: 64.87
# Actual: 57.0, Predicted: 59.02
# Actual: 58.0, Predicted: 56.59
# Actual: 38.0, Predicted: 38.55
# Actual: 22.0, Predicted: 20.71
# Actual: 48.0, Predicted: 46.34
# Actual: 59.0, Predicted: 56.62
# Actual: 58.0, Predicted: 55.45
# Actual: 62.0, Predicted: 64.76
# Actual: 30.0, Predicted: 28.76
# Actual: 56.0, Predicted: 55.01
# Actual: 40.0, Predicted: 41.24
# Actual: 59.0, Predicted: 56.57
# Actual: 65.0, Predicted: 65.20
# Actual: 43.0, Predicted: 41.53
# Actual: 48.0, Predicted: 45.49
# Actual: 24.0, Predicted: 23.88
# Actual: 51.0, Predicted: 47.96
# Actual: 81.0, Predicted: 76.62
# Actual: 62.0, Predicted: 61.95
# Actual: 43.0, Predicted: 41.23
# Actual: 63.0, Predicted: 58.38
# Actual: 73.0, Predicted: 74.62
# Actual: 76.0, Predicted: 81.33
# Actual: 43.0, Predicted: 40.93
# Actual: 34.0, Predicted: 34.96
# Actual: 57.0, Predicted: 59.26
# Actual: 72.0, Predicted: 73.35
# Actual: 47.0, Predicted: 50.02
# Actual: 52.0, Predicted: 48.91
# Actual: 49.0, Predicted: 45.22
# Actual: 77.0, Predicted: 77.60
# Actual: 41.0, Predicted: 41.52
# Actual: 56.0, Predicted: 54.81
# Actual: 89.0, Predicted: 85.12
# Actual: 65.0, Predicted: 67.05
# Actual: 49.0, Predicted: 49.15
# Actual: 48.0, Predicted: 45.22
# Actual: 47.0, Predicted: 47.07
# Actual: 37.0, Predicted: 39.19
# Actual: 48.0, Predicted: 47.79
# Actual: 61.0, Predicted: 64.97
# Actual: 77.0, Predicted: 76.93
# Actual: 75.0, Predicted: 75.48
# Actual: 57.0, Predicted: 55.42
# Actual: 45.0, Predicted: 46.56
# Actual: 82.0, Predicted: 80.48
# Actual: 90.0, Predicted: 89.28
# Actual: 42.0, Predicted: 44.21
# Actual: 74.0, Predicted: 75.80
# Actual: 60.0, Predicted: 56.57
# Actual: 73.0, Predicted: 71.54
# Actual: 40.0, Predicted: 44.07
# Actual: 32.0, Predicted: 32.71
# Actual: 67.0, Predicted: 66.42
# Actual: 46.0, Predicted: 45.58
# Actual: 65.0, Predicted: 64.13
# Actual: 42.0, Predicted: 41.73
# Actual: 69.0, Predicted: 69.01
# Actual: 62.0, Predicted: 61.36
# Actual: 75.0, Predicted: 77.18
# Actual: 40.0, Predicted: 41.03
# Actual: 43.0, Predicted: 47.56
# Actual: 42.0, Predicted: 44.35
# Actual: 84.0, Predicted: 84.95
# Actual: 15.0, Predicted: 15.93
# Actual: 39.0, Predicted: 37.13
# Actual: 26.0, Predicted: 29.51
# Actual: 73.0, Predicted: 74.41
# Actual: 34.0, Predicted: 32.99
# Actual: 34.0, Predicted: 37.21
# Actual: 37.0, Predicted: 34.47
# Actual: 34.0, Predicted: 33.64
# Actual: 85.0, Predicted: 83.21
# Actual: 31.0, Predicted: 32.49
# Actual: 18.0, Predicted: 19.68
# Actual: 92.0, Predicted: 92.35
# Actual: 44.0, Predicted: 41.81
# Actual: 72.0, Predicted: 71.10
# Actual: 40.0, Predicted: 39.23
# Actual: 31.0, Predicted: 31.92
# Actual: 25.0, Predicted: 26.51
# Actual: 44.0, Predicted: 42.03
# Actual: 27.0, Predicted: 27.20
# Actual: 66.0, Predicted: 69.32
# Actual: 34.0, Predicted: 36.32
# Actual: 70.0, Predicted: 71.53
# Actual: 81.0, Predicted: 80.99
# Actual: 56.0, Predicted: 55.94
# Actual: 30.0, Predicted: 32.50
# Actual: 60.0, Predicted: 61.76
# Actual: 64.0, Predicted: 64.85
# Actual: 74.0, Predicted: 74.21
# Actual: 52.0, Predicted: 52.98
# Actual: 84.0, Predicted: 78.36
# Actual: 66.0, Predicted: 65.72
# Actual: 32.0, Predicted: 32.85
# Actual: 47.0, Predicted: 49.84
# Actual: 51.0, Predicted: 48.99
# Actual: 67.0, Predicted: 70.77
# Actual: 57.0, Predicted: 60.91
# Actual: 71.0, Predicted: 70.99
# Actual: 86.0, Predicted: 84.08
# Actual: 77.0, Predicted: 76.75
# Actual: 72.0, Predicted: 68.35
# Actual: 24.0, Predicted: 25.27
# Actual: 60.0, Predicted: 60.89
# Actual: 55.0, Predicted: 55.67
# Actual: 54.0, Predicted: 53.47
# Actual: 39.0, Predicted: 39.90
# Actual: 19.0, Predicted: 19.44
# Actual: 68.0, Predicted: 70.22
# Actual: 83.0, Predicted: 81.39
# Actual: 72.0, Predicted: 70.58
# Actual: 49.0, Predicted: 49.95
# Actual: 74.0, Predicted: 74.18
# Actual: 86.0, Predicted: 83.36
# Actual: 26.0, Predicted: 28.06
# Actual: 60.0, Predicted: 59.68
# Actual: 54.0, Predicted: 53.96
# Actual: 73.0, Predicted: 69.13
# Actual: 61.0, Predicted: 56.60
# Actual: 45.0, Predicted: 43.97
# Actual: 57.0, Predicted: 49.48
# Actual: 68.0, Predicted: 67.98
# Actual: 72.0, Predicted: 81.12
# Actual: 17.0, Predicted: 18.70
# Actual: 37.0, Predicted: 37.92
# Actual: 54.0, Predicted: 50.89
# Actual: 22.0, Predicted: 22.29
# Actual: 73.0, Predicted: 69.67
# Actual: 47.0, Predicted: 46.04
# Actual: 63.0, Predicted: 62.29
# Actual: 63.0, Predicted: 62.02
# Actual: 68.0, Predicted: 66.89
# Actual: 52.0, Predicted: 49.36
# Actual: 64.0, Predicted: 64.00
# Actual: 38.0, Predicted: 39.27
# Actual: 60.0, Predicted: 59.27
# Actual: 45.0, Predicted: 44.77
# Actual: 39.0, Predicted: 40.05
# Actual: 75.0, Predicted: 69.95
# Actual: 67.0, Predicted: 64.90
# Actual: 48.0, Predicted: 49.33
# Actual: 44.0, Predicted: 42.96
# Actual: 37.0, Predicted: 38.90
# Actual: 41.0, Predicted: 43.49
# Actual: 47.0, Predicted: 45.14
# Actual: 45.0, Predicted: 46.16
# Actual: 43.0, Predicted: 42.48
# Actual: 54.0, Predicted: 56.64
# Actual: 32.0, Predicted: 32.22
# Actual: 64.0, Predicted: 64.25
# Actual: 74.0, Predicted: 74.08
# Actual: 50.0, Predicted: 46.04
# Actual: 33.0, Predicted: 29.58
# Actual: 36.0, Predicted: 36.07
# Actual: 45.0, Predicted: 45.41
# Actual: 58.0, Predicted: 58.82
# Actual: 85.0, Predicted: 85.85
# Actual: 41.0, Predicted: 42.04
# Actual: 78.0, Predicted: 74.92
# Actual: 63.0, Predicted: 69.31
# Actual: 76.0, Predicted: 74.41
# Actual: 51.0, Predicted: 48.50
# Actual: 36.0, Predicted: 39.56
# Actual: 74.0, Predicted: 74.17
# Actual: 65.0, Predicted: 66.47
# Actual: 65.0, Predicted: 65.08
# Actual: 79.0, Predicted: 78.56
# Actual: 46.0, Predicted: 45.53
# Actual: 47.0, Predicted: 49.72
# Actual: 42.0, Predicted: 38.31
# Actual: 46.0, Predicted: 46.58
# Actual: 34.0, Predicted: 29.16
# Actual: 27.0, Predicted: 28.45
# Actual: 52.0, Predicted: 53.81
# Actual: 17.0, Predicted: 16.56
# Actual: 53.0, Predicted: 50.90
# Actual: 84.0, Predicted: 80.72
# Actual: 39.0, Predicted: 41.67
# Actual: 44.0, Predicted: 44.16
# Actual: 36.0, Predicted: 32.42
# Actual: 81.0, Predicted: 81.21
# Actual: 30.0, Predicted: 28.17
# Actual: 80.0, Predicted: 84.02
# Actual: 41.0, Predicted: 43.96
# Actual: 77.0, Predicted: 75.10
# Actual: 69.0, Predicted: 69.33
# Actual: 34.0, Predicted: 32.86
# Actual: 64.0, Predicted: 65.66
# Actual: 78.0, Predicted: 81.27
# Actual: 74.0, Predicted: 73.93
# Actual: 52.0, Predicted: 54.65
# Actual: 76.0, Predicted: 75.47
# Actual: 53.0, Predicted: 55.70
# Actual: 46.0, Predicted: 44.39
# Actual: 77.0, Predicted: 77.67
# Actual: 59.0, Predicted: 58.96
# Actual: 35.0, Predicted: 34.09
# Actual: 61.0, Predicted: 59.07
# Actual: 46.0, Predicted: 46.33
# Actual: 97.0, Predicted: 92.67
# Actual: 86.0, Predicted: 82.54
# Actual: 24.0, Predicted: 25.48
# Actual: 37.0, Predicted: 39.37
# Actual: 18.0, Predicted: 20.13
# Actual: 84.0, Predicted: 80.11
# Actual: 59.0, Predicted: 61.28
# Actual: 29.0, Predicted: 30.45
# Actual: 84.0, Predicted: 84.30
# Actual: 60.0, Predicted: 55.95
# Actual: 78.0, Predicted: 80.46
# Actual: 46.0, Predicted: 43.97
# Actual: 31.0, Predicted: 31.44
# Actual: 68.0, Predicted: 67.72
# Actual: 25.0, Predicted: 25.82
# Actual: 37.0, Predicted: 38.43
# Actual: 62.0, Predicted: 63.64
# Actual: 69.0, Predicted: 70.69
# Actual: 50.0, Predicted: 53.44
# Actual: 55.0, Predicted: 57.47
# Actual: 54.0, Predicted: 51.87
# Actual: 12.0, Predicted: 13.08
# Actual: 88.0, Predicted: 86.55
# Actual: 69.0, Predicted: 69.34
# Actual: 88.0, Predicted: 87.61
# Actual: 41.0, Predicted: 41.09
# Actual: 83.0, Predicted: 82.01
# Actual: 62.0, Predicted: 63.94
# Actual: 45.0, Predicted: 45.50
# Actual: 42.0, Predicted: 39.53
# Actual: 65.0, Predicted: 63.63
# Actual: 73.0, Predicted: 69.76
# Actual: 23.0, Predicted: 24.83
# Actual: 61.0, Predicted: 62.36
# Actual: 41.0, Predicted: 41.37
# Actual: 85.0, Predicted: 87.15
# Actual: 93.0, Predicted: 90.83
# Actual: 35.0, Predicted: 34.33
# Actual: 92.0, Predicted: 92.12
# Actual: 79.0, Predicted: 76.34
# Actual: 57.0, Predicted: 58.35
# Actual: 49.0, Predicted: 47.24
# Actual: 28.0, Predicted: 24.91
# Actual: 85.0, Predicted: 83.93
# Actual: 82.0, Predicted: 81.27
# Actual: 80.0, Predicted: 80.32
# Actual: 41.0, Predicted: 44.18
# Actual: 57.0, Predicted: 57.48
# Actual: 41.0, Predicted: 37.24
# Actual: 43.0, Predicted: 39.16
# Actual: 73.0, Predicted: 72.30
# Actual: 46.0, Predicted: 46.39
# Actual: 61.0, Predicted: 58.97
# Actual: 61.0, Predicted: 60.22
# Actual: 87.0, Predicted: 85.08
# Actual: 78.0, Predicted: 79.21
# Actual: 43.0, Predicted: 42.86
# Actual: 75.0, Predicted: 76.50
# Actual: 72.0, Predicted: 71.83
# Actual: 18.0, Predicted: 19.71
# Actual: 36.0, Predicted: 35.96
# Actual: 92.0, Predicted: 91.22
# Actual: 71.0, Predicted: 69.86
# Actual: 58.0, Predicted: 58.26
# Actual: 69.0, Predicted: 65.56
# Actual: 58.0, Predicted: 59.87
# Actual: 74.0, Predicted: 76.83
# Actual: 72.0, Predicted: 73.05
# Actual: 61.0, Predicted: 61.33
# Actual: 74.0, Predicted: 70.73
# Actual: 60.0, Predicted: 60.56
# Actual: 70.0, Predicted: 71.80
# Actual: 27.0, Predicted: 28.99
# Actual: 49.0, Predicted: 49.10
# Actual: 17.0, Predicted: 19.67
# Actual: 34.0, Predicted: 30.36
# Actual: 51.0, Predicted: 55.90
# Actual: 27.0, Predicted: 28.75
# Actual: 67.0, Predicted: 67.85
# Actual: 84.0, Predicted: 85.40
# Actual: 81.0, Predicted: 79.06
# Actual: 45.0, Predicted: 47.09
# Actual: 50.0, Predicted: 48.77
# Actual: 67.0, Predicted: 63.53
# Actual: 67.0, Predicted: 64.17
# Actual: 77.0, Predicted: 76.19
# Actual: 70.0, Predicted: 70.59
# Actual: 59.0, Predicted: 56.59
# Actual: 27.0, Predicted: 28.04
# Actual: 88.0, Predicted: 89.20
# Actual: 60.0, Predicted: 61.63
# Actual: 14.0, Predicted: 13.92
# Actual: 27.0, Predicted: 29.23
# Actual: 54.0, Predicted: 55.43
# Actual: 32.0, Predicted: 27.30
# Actual: 79.0, Predicted: 77.28
# Actual: 44.0, Predicted: 43.06
# Actual: 20.0, Predicted: 20.95
# Actual: 42.0, Predicted: 40.25
# Actual: 33.0, Predicted: 35.52
# Actual: 58.0, Predicted: 61.43
# Actual: 31.0, Predicted: 32.20
# Actual: 75.0, Predicted: 76.95
# Actual: 22.0, Predicted: 20.53
# Actual: 46.0, Predicted: 44.67
# Actual: 68.0, Predicted: 68.20
# Actual: 66.0, Predicted: 64.68
# Actual: 60.0, Predicted: 59.18
# Actual: 44.0, Predicted: 45.92
# Actual: 90.0, Predicted: 88.18
# Actual: 47.0, Predicted: 45.80
# Actual: 88.0, Predicted: 89.20
# Actual: 56.0, Predicted: 56.62
# Actual: 66.0, Predicted: 63.90
# Actual: 78.0, Predicted: 80.83
# Actual: 43.0, Predicted: 41.75
# Actual: 72.0, Predicted: 71.24
# Actual: 69.0, Predicted: 69.94
# Actual: 24.0, Predicted: 23.87
# Actual: 47.0, Predicted: 46.86
# Actual: 45.0, Predicted: 48.48
# Actual: 72.0, Predicted: 71.34
# Actual: 51.0, Predicted: 52.49
# Actual: 73.0, Predicted: 71.13
# Actual: 28.0, Predicted: 30.72
# Actual: 56.0, Predicted: 60.31
# Actual: 29.0, Predicted: 32.37
# Actual: 60.0, Predicted: 60.27
# Actual: 28.0, Predicted: 31.57
# Actual: 66.0, Predicted: 68.88
# Actual: 21.0, Predicted: 23.15
# Actual: 84.0, Predicted: 82.00
# Actual: 42.0, Predicted: 43.56
# Actual: 51.0, Predicted: 51.42
# Actual: 74.0, Predicted: 74.80
# Actual: 50.0, Predicted: 52.84
# Actual: 62.0, Predicted: 61.30
# Actual: 90.0, Predicted: 84.35
# Actual: 32.0, Predicted: 35.82
# Actual: 71.0, Predicted: 72.53
# Actual: 37.0, Predicted: 39.59
# Actual: 42.0, Predicted: 42.38
# Actual: 85.0, Predicted: 86.99
# Actual: 96.0, Predicted: 93.89
# Actual: 51.0, Predicted: 47.67
# Actual: 82.0, Predicted: 80.78
# Actual: 64.0, Predicted: 62.18
# Actual: 67.0, Predicted: 66.32
# Actual: 32.0, Predicted: 29.14
# Actual: 50.0, Predicted: 50.77
# Actual: 73.0, Predicted: 74.16
# Actual: 62.0, Predicted: 60.62
# Actual: 48.0, Predicted: 48.63
# Actual: 20.0, Predicted: 16.05
# Actual: 33.0, Predicted: 31.05
# Actual: 43.0, Predicted: 44.13
# Actual: 49.0, Predicted: 50.17
# Actual: 70.0, Predicted: 70.12
# Actual: 28.0, Predicted: 29.32
# Actual: 82.0, Predicted: 79.41
# Actual: 29.0, Predicted: 30.26
# Actual: 42.0, Predicted: 43.10
# Actual: 79.0, Predicted: 80.54
# Actual: 41.0, Predicted: 41.35
# Actual: 61.0, Predicted: 59.63
# Actual: 69.0, Predicted: 67.31
# Actual: 68.0, Predicted: 69.33
# Actual: 38.0, Predicted: 35.78
# Actual: 67.0, Predicted: 65.39
# Actual: 54.0, Predicted: 53.57
# Actual: 39.0, Predicted: 37.15
# Actual: 93.0, Predicted: 90.08
# Actual: 76.0, Predicted: 74.88
# Actual: 39.0, Predicted: 39.00
# Actual: 38.0, Predicted: 41.62
# Actual: 69.0, Predicted: 68.31
# Actual: 88.0, Predicted: 87.10
# Actual: 54.0, Predicted: 52.63
# Actual: 68.0, Predicted: 69.49
# Actual: 33.0, Predicted: 34.14
# Actual: 40.0, Predicted: 38.06
# Actual: 87.0, Predicted: 87.06
# Actual: 64.0, Predicted: 63.68
# Actual: 70.0, Predicted: 74.06
# Actual: 70.0, Predicted: 69.82
# Actual: 72.0, Predicted: 71.13
# Actual: 38.0, Predicted: 37.12
# Actual: 71.0, Predicted: 71.26
# Actual: 40.0, Predicted: 42.47
# Actual: 58.0, Predicted: 61.60
# Actual: 77.0, Predicted: 78.65
# Actual: 38.0, Predicted: 35.82
# Actual: 60.0, Predicted: 60.29
# Actual: 57.0, Predicted: 55.04
# Actual: 63.0, Predicted: 60.16
# Actual: 82.0, Predicted: 81.36
# Actual: 84.0, Predicted: 82.42
# Actual: 84.0, Predicted: 81.55
# Actual: 77.0, Predicted: 79.71
# Actual: 61.0, Predicted: 62.48
# Actual: 73.0, Predicted: 75.74
# Actual: 15.0, Predicted: 18.41
# Actual: 64.0, Predicted: 64.92
# Actual: 33.0, Predicted: 33.91
# Actual: 78.0, Predicted: 81.41
# Actual: 43.0, Predicted: 42.35
# Actual: 34.0, Predicted: 35.57
# Actual: 48.0, Predicted: 44.63
# Actual: 66.0, Predicted: 65.63
# Actual: 60.0, Predicted: 59.88
# Actual: 53.0, Predicted: 52.80
# Actual: 51.0, Predicted: 51.51
# Actual: 43.0, Predicted: 42.11
# Actual: 68.0, Predicted: 66.12
# Actual: 80.0, Predicted: 82.50
# Actual: 26.0, Predicted: 28.33
# Actual: 70.0, Predicted: 70.21
# Actual: 85.0, Predicted: 84.74
# Actual: 57.0, Predicted: 55.78
# Actual: 30.0, Predicted: 31.95
# Actual: 56.0, Predicted: 53.71
# Actual: 53.0, Predicted: 52.92
# Actual: 52.0, Predicted: 52.10
# Actual: 47.0, Predicted: 45.00
# Actual: 48.0, Predicted: 47.09
# Actual: 78.0, Predicted: 73.27
# Actual: 79.0, Predicted: 77.49
# Actual: 75.0, Predicted: 72.43
# Actual: 40.0, Predicted: 39.90
# Actual: 59.0, Predicted: 56.16
# Actual: 49.0, Predicted: 49.50
# Actual: 48.0, Predicted: 52.58
# Actual: 60.0, Predicted: 58.02
# Actual: 29.0, Predicted: 27.64
# Actual: 68.0, Predicted: 69.93
# Actual: 63.0, Predicted: 62.72
# Actual: 71.0, Predicted: 70.60
# Actual: 76.0, Predicted: 73.23
# Actual: 57.0, Predicted: 56.26
# Actual: 54.0, Predicted: 53.43
# Actual: 61.0, Predicted: 64.14
# Actual: 34.0, Predicted: 38.35
# Actual: 32.0, Predicted: 29.61
# Actual: 23.0, Predicted: 22.90
# Actual: 44.0, Predicted: 43.65
# Actual: 18.0, Predicted: 17.87
# Actual: 82.0, Predicted: 82.00
# Actual: 18.0, Predicted: 22.01
# Actual: 52.0, Predicted: 50.97
# Actual: 88.0, Predicted: 86.02
# Actual: 78.0, Predicted: 78.81
# Actual: 26.0, Predicted: 26.80
# Actual: 26.0, Predicted: 26.91
# Actual: 74.0, Predicted: 69.69
# Actual: 52.0, Predicted: 49.65
# Actual: 40.0, Predicted: 41.78
# Actual: 54.0, Predicted: 53.41
# Actual: 51.0, Predicted: 53.37
# Actual: 35.0, Predicted: 36.02
# Actual: 79.0, Predicted: 79.33
# Actual: 45.0, Predicted: 47.37
# Actual: 81.0, Predicted: 83.09
# Actual: 87.0, Predicted: 83.99
# Actual: 56.0, Predicted: 55.42
# Actual: 65.0, Predicted: 62.51
# Actual: 38.0, Predicted: 38.97
# Actual: 17.0, Predicted: 20.35
# Actual: 35.0, Predicted: 33.39
# Actual: 20.0, Predicted: 20.04
# Actual: 75.0, Predicted: 75.67
# Actual: 26.0, Predicted: 23.73
# Actual: 23.0, Predicted: 25.97
# Actual: 38.0, Predicted: 35.61
# Actual: 78.0, Predicted: 76.84
# Actual: 91.0, Predicted: 90.89
# Actual: 67.0, Predicted: 70.40
# Actual: 31.0, Predicted: 29.69
# Actual: 49.0, Predicted: 46.66
# Actual: 57.0, Predicted: 56.43
# Actual: 45.0, Predicted: 44.68
# Actual: 22.0, Predicted: 25.24
# Actual: 35.0, Predicted: 37.51
# Actual: 65.0, Predicted: 66.50
# Actual: 53.0, Predicted: 56.42
# Actual: 79.0, Predicted: 82.46
# Actual: 57.0, Predicted: 58.17
# Actual: 58.0, Predicted: 60.37
# Actual: 50.0, Predicted: 49.84
# Actual: 75.0, Predicted: 74.51
# Actual: 17.0, Predicted: 20.40
# Actual: 70.0, Predicted: 68.73
# Actual: 36.0, Predicted: 34.49
# Actual: 61.0, Predicted: 65.58
# Actual: 78.0, Predicted: 74.52
# Actual: 71.0, Predicted: 69.76
# Actual: 36.0, Predicted: 35.45
# Actual: 63.0, Predicted: 60.04
# Actual: 78.0, Predicted: 78.10
# Actual: 39.0, Predicted: 40.81
# Actual: 70.0, Predicted: 73.34
# Actual: 34.0, Predicted: 34.96
# Actual: 49.0, Predicted: 49.14
# Actual: 71.0, Predicted: 74.12
# Actual: 34.0, Predicted: 35.08
# Actual: 77.0, Predicted: 73.39
# Actual: 67.0, Predicted: 65.29
# Actual: 52.0, Predicted: 55.65
# Actual: 25.0, Predicted: 23.78
# Actual: 68.0, Predicted: 66.89
# Actual: 76.0, Predicted: 72.70
# Actual: 85.0, Predicted: 84.42
# Actual: 40.0, Predicted: 37.84
# Actual: 56.0, Predicted: 55.27
# Actual: 62.0, Predicted: 62.20
# Actual: 99.0, Predicted: 98.10
# Actual: 46.0, Predicted: 46.22
# Actual: 86.0, Predicted: 85.23
# Actual: 73.0, Predicted: 71.68
# Actual: 74.0, Predicted: 73.95
# Actual: 37.0, Predicted: 36.24
# Actual: 50.0, Predicted: 50.69
# Actual: 65.0, Predicted: 66.13
# Actual: 79.0, Predicted: 79.28
# Actual: 53.0, Predicted: 54.67
# Actual: 55.0, Predicted: 52.36
# Actual: 31.0, Predicted: 30.04
# Actual: 47.0, Predicted: 46.06
# Actual: 63.0, Predicted: 62.04
# Actual: 27.0, Predicted: 26.86
# Actual: 53.0, Predicted: 56.05
# Actual: 33.0, Predicted: 30.43
# Actual: 56.0, Predicted: 52.45
# Actual: 65.0, Predicted: 63.35
# Actual: 55.0, Predicted: 56.30
# Actual: 67.0, Predicted: 65.76
# Actual: 32.0, Predicted: 33.95
# Actual: 73.0, Predicted: 73.96
# Actual: 45.0, Predicted: 49.70
# Actual: 43.0, Predicted: 40.53
# Actual: 32.0, Predicted: 31.34
# Actual: 42.0, Predicted: 41.09
# Actual: 55.0, Predicted: 53.10
# Actual: 28.0, Predicted: 26.96
# Actual: 58.0, Predicted: 55.34
# Actual: 67.0, Predicted: 64.16
# Actual: 66.0, Predicted: 66.34
# Actual: 46.0, Predicted: 49.08
# Actual: 79.0, Predicted: 80.39
# Actual: 83.0, Predicted: 82.43
# Actual: 63.0, Predicted: 64.73
# Actual: 45.0, Predicted: 44.99
# Actual: 63.0, Predicted: 58.53
# Actual: 70.0, Predicted: 67.46
# Actual: 58.0, Predicted: 62.43
# Actual: 50.0, Predicted: 44.70
# Actual: 77.0, Predicted: 73.74
# Actual: 75.0, Predicted: 73.61
# Actual: 40.0, Predicted: 39.59
# Actual: 43.0, Predicted: 45.81
# Actual: 47.0, Predicted: 47.25
# Actual: 22.0, Predicted: 26.57
# Actual: 71.0, Predicted: 68.93
# Actual: 63.0, Predicted: 62.42
# Actual: 37.0, Predicted: 37.95
# Actual: 72.0, Predicted: 69.68
# Actual: 73.0, Predicted: 72.73
# Actual: 72.0, Predicted: 67.90
# Actual: 68.0, Predicted: 68.76
# Actual: 59.0, Predicted: 56.25
# Actual: 97.0, Predicted: 95.85
# Actual: 83.0, Predicted: 84.80
# Actual: 65.0, Predicted: 63.86
# Actual: 47.0, Predicted: 46.51
# Actual: 51.0, Predicted: 49.49
# Actual: 32.0, Predicted: 33.81
# Actual: 63.0, Predicted: 67.73
# Actual: 60.0, Predicted: 60.91
# Actual: 70.0, Predicted: 69.34
# Actual: 32.0, Predicted: 30.98
# Actual: 32.0, Predicted: 32.32
# Actual: 29.0, Predicted: 29.17
# Actual: 21.0, Predicted: 21.84
# Actual: 74.0, Predicted: 73.65
# Actual: 81.0, Predicted: 78.53
# Actual: 11.0, Predicted: 14.02
# Actual: 65.0, Predicted: 61.21
# Actual: 37.0, Predicted: 36.56
# Actual: 75.0, Predicted: 71.06
# Actual: 61.0, Predicted: 57.35
# Actual: 17.0, Predicted: 22.25
# Actual: 87.0, Predicted: 86.97
# Actual: 52.0, Predicted: 54.35
# Actual: 71.0, Predicted: 71.45
# Actual: 46.0, Predicted: 45.78
# Actual: 99.0, Predicted: 96.08
# Actual: 40.0, Predicted: 42.77
# Actual: 42.0, Predicted: 36.75
# Actual: 91.0, Predicted: 91.36
# Actual: 57.0, Predicted: 59.72
# Actual: 58.0, Predicted: 55.21
# Actual: 55.0, Predicted: 55.34
# Actual: 46.0, Predicted: 42.18
# Actual: 64.0, Predicted: 65.93
# Actual: 45.0, Predicted: 44.76
# Actual: 78.0, Predicted: 74.69
# Actual: 24.0, Predicted: 25.63
# Actual: 36.0, Predicted: 34.04
# Actual: 65.0, Predicted: 63.66
# Actual: 35.0, Predicted: 37.64
# Actual: 87.0, Predicted: 84.17
# Actual: 45.0, Predicted: 45.95
# Actual: 35.0, Predicted: 32.55
# Actual: 18.0, Predicted: 19.33
# Actual: 46.0, Predicted: 48.12
# Actual: 63.0, Predicted: 63.65
# Actual: 62.0, Predicted: 62.45
# Actual: 35.0, Predicted: 34.94
# Actual: 63.0, Predicted: 61.81
# Actual: 58.0, Predicted: 54.43
# Actual: 37.0, Predicted: 36.77
# Actual: 74.0, Predicted: 71.25
# Actual: 40.0, Predicted: 38.96
# Actual: 78.0, Predicted: 77.94
# Actual: 38.0, Predicted: 36.96
# Actual: 55.0, Predicted: 54.99
# Actual: 39.0, Predicted: 36.85
# Actual: 84.0, Predicted: 81.25
# Actual: 60.0, Predicted: 62.46
# Actual: 47.0, Predicted: 45.03
# Actual: 34.0, Predicted: 33.21
# Actual: 54.0, Predicted: 53.16
# Actual: 56.0, Predicted: 56.79
# Actual: 82.0, Predicted: 79.81
# Actual: 45.0, Predicted: 43.20
# Actual: 45.0, Predicted: 44.95
# Actual: 43.0, Predicted: 41.02
# Actual: 57.0, Predicted: 58.52
# Actual: 56.0, Predicted: 56.69
# Actual: 56.0, Predicted: 55.40
# Actual: 30.0, Predicted: 29.94
# Actual: 75.0, Predicted: 75.60
# Actual: 33.0, Predicted: 34.89
# Actual: 80.0, Predicted: 78.28
# Actual: 27.0, Predicted: 23.04
# Actual: 26.0, Predicted: 25.58
# Actual: 81.0, Predicted: 81.46
# Actual: 41.0, Predicted: 37.74
# Actual: 34.0, Predicted: 34.60
# Actual: 68.0, Predicted: 66.12
# Actual: 83.0, Predicted: 81.66
# Actual: 44.0, Predicted: 46.93
# Actual: 75.0, Predicted: 74.12
# Actual: 52.0, Predicted: 47.43
# Actual: 56.0, Predicted: 58.13
# Actual: 37.0, Predicted: 34.35
# Actual: 67.0, Predicted: 65.08
# Actual: 50.0, Predicted: 50.35
# Actual: 46.0, Predicted: 45.48
# Actual: 31.0, Predicted: 33.43
# Actual: 51.0, Predicted: 49.20
# Actual: 82.0, Predicted: 83.45
# Actual: 58.0, Predicted: 56.45
# Actual: 31.0, Predicted: 26.88
# Actual: 29.0, Predicted: 29.57
# Actual: 40.0, Predicted: 39.36
# Actual: 51.0, Predicted: 53.60
# Actual: 79.0, Predicted: 78.40
# Actual: 52.0, Predicted: 53.03
# Actual: 36.0, Predicted: 35.86
# Actual: 43.0, Predicted: 43.70
# Actual: 81.0, Predicted: 81.97
# Actual: 81.0, Predicted: 80.21
# Actual: 84.0, Predicted: 88.52
# Actual: 55.0, Predicted: 56.68
# Actual: 64.0, Predicted: 59.00
# Actual: 68.0, Predicted: 68.21
# Actual: 41.0, Predicted: 41.79
# Actual: 53.0, Predicted: 51.70
# Actual: 50.0, Predicted: 48.10
# Actual: 65.0, Predicted: 61.60
# Actual: 78.0, Predicted: 78.01
# Actual: 31.0, Predicted: 31.15
# Actual: 30.0, Predicted: 29.81
# Actual: 64.0, Predicted: 63.86
# Actual: 26.0, Predicted: 25.91
# Actual: 66.0, Predicted: 64.42
# Actual: 55.0, Predicted: 54.06
# Actual: 52.0, Predicted: 50.66
# Actual: 57.0, Predicted: 51.36
# Actual: 68.0, Predicted: 63.96
# Actual: 57.0, Predicted: 55.06
# Actual: 75.0, Predicted: 71.48
# Actual: 54.0, Predicted: 55.50
# Actual: 82.0, Predicted: 80.55
# Actual: 51.0, Predicted: 49.62
# Actual: 43.0, Predicted: 39.72
# Actual: 68.0, Predicted: 70.30
# Actual: 77.0, Predicted: 77.92
# Actual: 33.0, Predicted: 32.79
# Actual: 37.0, Predicted: 33.90
# Actual: 23.0, Predicted: 22.54
# Actual: 26.0, Predicted: 24.32
# Actual: 56.0, Predicted: 56.71
# Actual: 42.0, Predicted: 41.17
# Actual: 65.0, Predicted: 66.53
# Actual: 66.0, Predicted: 67.47
# Actual: 57.0, Predicted: 56.61
# Actual: 59.0, Predicted: 60.89
# Actual: 28.0, Predicted: 29.99
# Actual: 46.0, Predicted: 46.14
# Actual: 84.0, Predicted: 86.36
# Actual: 42.0, Predicted: 42.34
# Actual: 73.0, Predicted: 72.32
# Actual: 77.0, Predicted: 78.53
# Actual: 74.0, Predicted: 74.16
# Actual: 75.0, Predicted: 75.83
# Actual: 94.0, Predicted: 90.28
# Actual: 27.0, Predicted: 26.74
# Actual: 89.0, Predicted: 83.90
# Actual: 62.0, Predicted: 63.02
# Actual: 59.0, Predicted: 59.39
# Actual: 73.0, Predicted: 70.97
# Actual: 57.0, Predicted: 61.84
# Actual: 90.0, Predicted: 88.80
# Actual: 80.0, Predicted: 79.23
# Actual: 50.0, Predicted: 49.12
# Actual: 18.0, Predicted: 18.94
# Actual: 68.0, Predicted: 66.60
# Actual: 39.0, Predicted: 42.95
# Actual: 67.0, Predicted: 67.90
# Actual: 69.0, Predicted: 65.14
# Actual: 43.0, Predicted: 42.98
# Actual: 84.0, Predicted: 86.55
# Actual: 50.0, Predicted: 50.03
# Actual: 65.0, Predicted: 63.21
# Actual: 74.0, Predicted: 73.45
# Actual: 35.0, Predicted: 35.62
# Actual: 61.0, Predicted: 62.04
# Actual: 64.0, Predicted: 66.03
# Actual: 66.0, Predicted: 70.23
# Actual: 81.0, Predicted: 83.08
# Actual: 93.0, Predicted: 89.92
# Actual: 28.0, Predicted: 29.51
# Actual: 71.0, Predicted: 70.63
# Actual: 13.0, Predicted: 16.31
# Actual: 59.0, Predicted: 58.99
# Actual: 67.0, Predicted: 67.00
# Actual: 35.0, Predicted: 35.21
# Actual: 46.0, Predicted: 46.62
# Actual: 59.0, Predicted: 59.32
# Actual: 57.0, Predicted: 57.36
# Actual: 51.0, Predicted: 50.40
# Actual: 80.0, Predicted: 85.08
# Actual: 22.0, Predicted: 25.25
# Actual: 71.0, Predicted: 71.85
# Actual: 73.0, Predicted: 70.03
# Actual: 40.0, Predicted: 42.43
# Actual: 75.0, Predicted: 73.22
# Actual: 24.0, Predicted: 21.13
# Actual: 45.0, Predicted: 45.15
# Actual: 25.0, Predicted: 25.45
# Actual: 42.0, Predicted: 41.38
# Actual: 63.0, Predicted: 62.46
# Actual: 44.0, Predicted: 45.09
# Actual: 26.0, Predicted: 24.98
# Actual: 31.0, Predicted: 32.44
# Actual: 26.0, Predicted: 23.94
# Actual: 15.0, Predicted: 16.09
# Actual: 77.0, Predicted: 76.23
# Actual: 31.0, Predicted: 28.05
# Actual: 75.0, Predicted: 75.51
# Actual: 34.0, Predicted: 36.43
# Actual: 74.0, Predicted: 75.23
# Actual: 68.0, Predicted: 67.58
# Actual: 64.0, Predicted: 64.25
# Actual: 43.0, Predicted: 43.94
# Actual: 54.0, Predicted: 52.46
# Actual: 53.0, Predicted: 52.18
# Actual: 56.0, Predicted: 57.07
# Actual: 34.0, Predicted: 33.70
# Actual: 27.0, Predicted: 28.98
# Actual: 66.0, Predicted: 66.74
# Actual: 41.0, Predicted: 45.45
# Actual: 25.0, Predicted: 26.22
# Actual: 20.0, Predicted: 17.93
# Actual: 45.0, Predicted: 43.42
# Actual: 70.0, Predicted: 68.84
# Actual: 86.0, Predicted: 84.64
# Actual: 46.0, Predicted: 46.72
# Actual: 73.0, Predicted: 75.36
# Actual: 42.0, Predicted: 42.92
# Actual: 27.0, Predicted: 32.74
# Actual: 64.0, Predicted: 62.08
# Actual: 71.0, Predicted: 71.08
# Actual: 56.0, Predicted: 54.46
# Actual: 43.0, Predicted: 43.45
# Actual: 50.0, Predicted: 53.36
# Actual: 31.0, Predicted: 30.57
# Actual: 42.0, Predicted: 41.68
# Actual: 60.0, Predicted: 60.70
# Actual: 76.0, Predicted: 74.57
# Actual: 28.0, Predicted: 28.56
# Actual: 45.0, Predicted: 44.24
# Actual: 71.0, Predicted: 70.71
# Actual: 44.0, Predicted: 41.28
# Actual: 48.0, Predicted: 45.95
# Actual: 57.0, Predicted: 59.47
# Actual: 61.0, Predicted: 61.58
# Actual: 86.0, Predicted: 86.90
# Actual: 95.0, Predicted: 93.02
# Actual: 70.0, Predicted: 70.86
# Actual: 81.0, Predicted: 82.38
# Actual: 18.0, Predicted: 17.96
# Actual: 24.0, Predicted: 23.25
# Actual: 32.0, Predicted: 35.10
# Actual: 40.0, Predicted: 40.36
# Actual: 25.0, Predicted: 23.30
# Actual: 41.0, Predicted: 41.73
# Actual: 66.0, Predicted: 62.17
# Actual: 83.0, Predicted: 84.83
# Actual: 22.0, Predicted: 23.18
# Actual: 70.0, Predicted: 68.52
# Actual: 42.0, Predicted: 41.95
# Actual: 56.0, Predicted: 55.69
# Actual: 72.0, Predicted: 73.61
# Actual: 31.0, Predicted: 32.39
# Actual: 60.0, Predicted: 56.75
# Actual: 74.0, Predicted: 74.24
# Actual: 62.0, Predicted: 61.45
# Actual: 44.0, Predicted: 45.54
# Actual: 46.0, Predicted: 46.18
# Actual: 96.0, Predicted: 96.54
# Actual: 51.0, Predicted: 53.35
# Actual: 43.0, Predicted: 45.26
# Actual: 51.0, Predicted: 51.61
# Actual: 58.0, Predicted: 53.19
# Actual: 23.0, Predicted: 19.31
# Actual: 67.0, Predicted: 71.18
# Actual: 50.0, Predicted: 51.90
# Actual: 31.0, Predicted: 31.80
# Actual: 83.0, Predicted: 83.43
# Actual: 55.0, Predicted: 54.60
# Actual: 44.0, Predicted: 40.79
# Actual: 45.0, Predicted: 46.30
# Actual: 73.0, Predicted: 68.82
# Actual: 76.0, Predicted: 73.81
# Actual: 23.0, Predicted: 23.97
# Actual: 84.0, Predicted: 85.93
# Actual: 73.0, Predicted: 74.59
# Actual: 48.0, Predicted: 44.26
# Actual: 50.0, Predicted: 48.92
# Actual: 30.0, Predicted: 29.16
# Actual: 51.0, Predicted: 55.08
# Actual: 76.0, Predicted: 76.85
# Actual: 66.0, Predicted: 66.26
# Actual: 50.0, Predicted: 49.87
# Actual: 40.0, Predicted: 40.46
# Actual: 42.0, Predicted: 42.90
# Actual: 29.0, Predicted: 28.63
# Actual: 77.0, Predicted: 75.57
# Actual: 45.0, Predicted: 46.29
# Actual: 49.0, Predicted: 50.96
# Actual: 74.0, Predicted: 75.70
# Actual: 45.0, Predicted: 46.95
# Actual: 27.0, Predicted: 27.44
# Actual: 44.0, Predicted: 40.19
# Actual: 42.0, Predicted: 43.20
# Actual: 43.0, Predicted: 45.67
# Actual: 68.0, Predicted: 69.02
# Actual: 29.0, Predicted: 25.83
# Actual: 73.0, Predicted: 73.40
# Actual: 39.0, Predicted: 40.74
# Actual: 30.0, Predicted: 32.79
# Actual: 53.0, Predicted: 54.43
# Actual: 38.0, Predicted: 41.11
# Actual: 82.0, Predicted: 81.52
# Actual: 72.0, Predicted: 72.97
# Actual: 24.0, Predicted: 29.42
# Actual: 44.0, Predicted: 41.07
# Actual: 45.0, Predicted: 41.18
# Actual: 75.0, Predicted: 73.84
# Actual: 75.0, Predicted: 71.44
# Actual: 26.0, Predicted: 24.85
# Actual: 49.0, Predicted: 51.94
# Actual: 42.0, Predicted: 41.97
# Actual: 14.0, Predicted: 15.44
# Actual: 64.0, Predicted: 67.06
# Actual: 54.0, Predicted: 54.66
# Actual: 16.0, Predicted: 17.22
# Actual: 73.0, Predicted: 72.86
# Actual: 67.0, Predicted: 66.35
# Actual: 69.0, Predicted: 64.79
# Actual: 28.0, Predicted: 28.54
# Actual: 67.0, Predicted: 68.83
# Actual: 62.0, Predicted: 63.33
# Actual: 60.0, Predicted: 61.46
# Actual: 43.0, Predicted: 38.31
# Actual: 70.0, Predicted: 70.35
# Actual: 70.0, Predicted: 68.98
# Actual: 84.0, Predicted: 81.28
# Actual: 72.0, Predicted: 69.68
# Actual: 44.0, Predicted: 43.07
# Actual: 46.0, Predicted: 47.53
# Actual: 41.0, Predicted: 42.74
# Actual: 58.0, Predicted: 60.88
# Actual: 44.0, Predicted: 41.29
# Actual: 89.0, Predicted: 83.25
# Actual: 45.0, Predicted: 41.68
# Actual: 87.0, Predicted: 86.55
# Actual: 61.0, Predicted: 63.48
# Actual: 41.0, Predicted: 41.95
# Actual: 57.0, Predicted: 55.34
# Actual: 62.0, Predicted: 62.54
# Actual: 39.0, Predicted: 39.94
# Actual: 54.0, Predicted: 53.41
# Actual: 33.0, Predicted: 32.96
# Actual: 42.0, Predicted: 37.44
# Actual: 70.0, Predicted: 64.75
# Actual: 67.0, Predicted: 67.58
# Actual: 80.0, Predicted: 78.42
# Actual: 44.0, Predicted: 46.71
# Actual: 69.0, Predicted: 67.28
# Actual: 66.0, Predicted: 65.01
# Actual: 35.0, Predicted: 36.17
# Actual: 61.0, Predicted: 59.28
# Actual: 68.0, Predicted: 70.23
# Actual: 55.0, Predicted: 54.63
# Actual: 36.0, Predicted: 35.91
# Actual: 56.0, Predicted: 60.26
# Actual: 58.0, Predicted: 57.44
# Actual: 40.0, Predicted: 41.57
# Actual: 68.0, Predicted: 68.57
# Actual: 43.0, Predicted: 42.03
# Actual: 61.0, Predicted: 64.11
# Actual: 45.0, Predicted: 46.28
# Actual: 36.0, Predicted: 35.78
# Actual: 67.0, Predicted: 67.46
# Actual: 67.0, Predicted: 68.89
# Actual: 29.0, Predicted: 31.23
# Actual: 31.0, Predicted: 33.12
# Actual: 74.0, Predicted: 77.61
# Actual: 37.0, Predicted: 38.49
# Actual: 79.0, Predicted: 75.55
# Actual: 76.0, Predicted: 79.75
# Actual: 45.0, Predicted: 43.40
# Actual: 65.0, Predicted: 68.23
# Actual: 72.0, Predicted: 70.98
# Actual: 62.0, Predicted: 56.59
# Actual: 19.0, Predicted: 17.72
# Actual: 39.0, Predicted: 39.82
# Actual: 93.0, Predicted: 92.82
# Actual: 62.0, Predicted: 60.63
# Actual: 37.0, Predicted: 35.95
# Actual: 34.0, Predicted: 34.15
# Actual: 23.0, Predicted: 24.05
# Actual: 79.0, Predicted: 79.03
# Actual: 51.0, Predicted: 55.84
# Actual: 18.0, Predicted: 19.68
# Actual: 41.0, Predicted: 36.91
# Actual: 57.0, Predicted: 55.44
# Actual: 36.0, Predicted: 35.81
# Actual: 47.0, Predicted: 49.02
# Actual: 65.0, Predicted: 61.31
# Actual: 57.0, Predicted: 57.90
# Actual: 22.0, Predicted: 23.93
# Actual: 20.0, Predicted: 19.88
# Actual: 27.0, Predicted: 27.63
# Actual: 64.0, Predicted: 68.23
# Actual: 32.0, Predicted: 35.05
# Actual: 29.0, Predicted: 28.77
# Actual: 62.0, Predicted: 64.29
# Actual: 56.0, Predicted: 59.72
# Actual: 43.0, Predicted: 46.99
# Actual: 70.0, Predicted: 70.39
# Actual: 49.0, Predicted: 48.79
# Actual: 68.0, Predicted: 66.14
# ...
# Actual: 53.0, Predicted: 56.23
# Actual: 76.0, Predicted: 76.04
# Actual: 54.0, Predicted: 53.86
# Actual: 80.0, Predicted: 80.98
# Actual: 68.0, Predicted: 68.94
# Actual: 63.0, Predicted: 59.83
# Actual: 46.0, Predicted: 46.11
# Actual: 45.0, Predicted: 44.51
# Actual: 43.0, Predicted: 41.59
# Actual: 83.0, Predicted: 81.61
# Actual: 56.0, Predicted: 56.14
# Actual: 29.0, Predicted: 32.78
# Actual: 79.0, Predicted: 76.92
# Actual: 40.0, Predicted: 39.90
# Actual: 55.0, Predicted: 55.93
# Actual: 55.0, Predicted: 56.33
# Actual: 65.0, Predicted: 63.69
# Actual: 41.0, Predicted: 42.13
# Actual: 53.0, Predicted: 53.67
# Actual: 41.0, Predicted: 39.83
# Actual: 34.0, Predicted: 34.82
# Actual: 23.0, Predicted: 25.17
# Actual: 70.0, Predicted: 69.24
# Actual: 38.0, Predicted: 38.18
# Actual: 45.0, Predicted: 43.21
# Actual: 14.0, Predicted: 15.59
# Actual: 37.0, Predicted: 36.85
# Actual: 33.0, Predicted: 31.79
# Actual: 81.0, Predicted: 83.70
# Actual: 68.0, Predicted: 66.38
# Actual: 76.0, Predicted: 72.08
# Actual: 74.0, Predicted: 73.07
# Actual: 41.0, Predicted: 40.62
# Actual: 70.0, Predicted: 68.69
# Actual: 89.0, Predicted: 87.86
# Actual: 25.0, Predicted: 24.24
# Actual: 36.0, Predicted: 36.64
# Actual: 27.0, Predicted: 28.62
# Actual: 71.0, Predicted: 72.24
# Actual: 56.0, Predicted: 58.39
# Actual: 41.0, Predicted: 38.36
# Actual: 41.0, Predicted: 42.68
# Actual: 34.0, Predicted: 34.50
# Actual: 23.0, Predicted: 24.46
# Actual: 78.0, Predicted: 77.42
# Actual: 76.0, Predicted: 74.55
# Actual: 78.0, Predicted: 81.08
# Actual: 38.0, Predicted: 37.46
# Actual: 48.0, Predicted: 49.96
# Actual: 65.0, Predicted: 67.08
# Actual: 59.0, Predicted: 53.80
# Actual: 52.0, Predicted: 50.95
# Actual: 97.0, Predicted: 94.80
# Actual: 54.0, Predicted: 53.98
# Actual: 34.0, Predicted: 34.35
# Actual: 80.0, Predicted: 80.94
# Actual: 54.0, Predicted: 50.42
# Actual: 63.0, Predicted: 58.46
# Actual: 26.0, Predicted: 26.19
# Actual: 85.0, Predicted: 82.08
# Actual: 40.0, Predicted: 38.39
# Actual: 68.0, Predicted: 67.80
# Actual: 32.0, Predicted: 32.86
# Actual: 44.0, Predicted: 44.13
# Actual: 70.0, Predicted: 66.03
# Actual: 66.0, Predicted: 65.14
# Actual: 76.0, Predicted: 75.62
# Actual: 29.0, Predicted: 29.98
# Actual: 70.0, Predicted: 68.43
# Actual: 64.0, Predicted: 66.83
# Actual: 76.0, Predicted: 76.65
# Actual: 72.0, Predicted: 72.92
# Actual: 24.0, Predicted: 25.67
# Actual: 40.0, Predicted: 40.65
# Actual: 37.0, Predicted: 35.67
# Actual: 42.0, Predicted: 38.34
# Actual: 28.0, Predicted: 27.65
# Actual: 61.0, Predicted: 61.33
# Actual: 53.0, Predicted: 51.52
# Actual: 50.0, Predicted: 50.17
# Actual: 55.0, Predicted: 58.57
# Actual: 67.0, Predicted: 63.80
# Actual: 79.0, Predicted: 80.91
# Actual: 77.0, Predicted: 76.81
# Actual: 26.0, Predicted: 28.65
# Actual: 26.0, Predicted: 27.36
# Actual: 44.0, Predicted: 44.64
# Actual: 80.0, Predicted: 85.03
# Actual: 73.0, Predicted: 73.69
# Actual: 61.0, Predicted: 60.00
# Actual: 53.0, Predicted: 52.03
# Actual: 59.0, Predicted: 62.78
# Actual: 40.0, Predicted: 38.29
# Actual: 88.0, Predicted: 83.18
# Actual: 76.0, Predicted: 72.04
# Actual: 65.0, Predicted: 66.26
# Actual: 23.0, Predicted: 24.66
# Actual: 50.0, Predicted: 51.08
# Actual: 59.0, Predicted: 54.75
# Actual: 57.0, Predicted: 58.33
# Actual: 14.0, Predicted: 15.08
# Actual: 41.0, Predicted: 39.38
# Actual: 81.0, Predicted: 78.54
# Actual: 47.0, Predicted: 44.97
# Actual: 67.0, Predicted: 68.62
# Actual: 92.0, Predicted: 90.65
# Actual: 95.0, Predicted: 91.78
# Actual: 79.0, Predicted: 79.37
# Actual: 24.0, Predicted: 23.47
# Actual: 67.0, Predicted: 66.27
# Actual: 30.0, Predicted: 30.31
# Actual: 91.0, Predicted: 90.19
# Actual: 21.0, Predicted: 19.39
# Actual: 87.0, Predicted: 83.85
# Actual: 69.0, Predicted: 69.35
# Actual: 72.0, Predicted: 71.72
# Actual: 70.0, Predicted: 71.12
# Actual: 66.0, Predicted: 62.42
# Actual: 55.0, Predicted: 56.13
# Actual: 60.0, Predicted: 59.64
# Actual: 67.0, Predicted: 66.36
# Actual: 65.0, Predicted: 63.95
# Actual: 87.0, Predicted: 89.41
# Actual: 48.0, Predicted: 46.93
# Actual: 87.0, Predicted: 85.71
# Actual: 84.0, Predicted: 83.92
# Actual: 32.0, Predicted: 31.36
# Actual: 27.0, Predicted: 27.18
# Actual: 37.0, Predicted: 40.51
# Actual: 43.0, Predicted: 40.34
# Actual: 77.0, Predicted: 78.79
# Actual: 65.0, Predicted: 67.14
# Actual: 43.0, Predicted: 40.81
# Actual: 64.0, Predicted: 66.48
# Actual: 43.0, Predicted: 43.44
# Actual: 57.0, Predicted: 54.10
# Actual: 73.0, Predicted: 73.17
# Actual: 32.0, Predicted: 35.28
# Actual: 85.0, Predicted: 83.34
# Actual: 54.0, Predicted: 52.72
# Actual: 81.0, Predicted: 81.10
# Actual: 79.0, Predicted: 83.25
# Actual: 58.0, Predicted: 55.01
# Actual: 53.0, Predicted: 49.10
# Actual: 25.0, Predicted: 25.00
# Actual: 41.0, Predicted: 42.72
# Actual: 44.0, Predicted: 43.10
# Actual: 70.0, Predicted: 69.42
# Actual: 29.0, Predicted: 28.15
# Actual: 34.0, Predicted: 34.45
# Actual: 56.0, Predicted: 54.06
# Actual: 49.0, Predicted: 47.29
# Actual: 78.0, Predicted: 73.18
# Actual: 88.0, Predicted: 86.47
# Actual: 45.0, Predicted: 44.58
# Actual: 77.0, Predicted: 79.58
# Actual: 76.0, Predicted: 79.79
# Actual: 70.0, Predicted: 70.05
# Actual: 80.0, Predicted: 80.84
# Actual: 45.0, Predicted: 46.94
# Actual: 71.0, Predicted: 72.96
# Actual: 42.0, Predicted: 39.92
# Actual: 65.0, Predicted: 66.00
# Actual: 56.0, Predicted: 57.22
# Actual: 93.0, Predicted: 95.27
# Actual: 62.0, Predicted: 64.28
# Actual: 52.0, Predicted: 52.81
# Actual: 24.0, Predicted: 24.06
# Actual: 61.0, Predicted: 60.92
# Actual: 78.0, Predicted: 78.74
# Actual: 28.0, Predicted: 32.40
# Actual: 86.0, Predicted: 87.32
# Actual: 69.0, Predicted: 69.86
# Actual: 71.0, Predicted: 68.99
# Actual: 91.0, Predicted: 91.44
# Actual: 79.0, Predicted: 77.73
# Actual: 41.0, Predicted: 38.57
# Actual: 36.0, Predicted: 37.19
# Actual: 57.0, Predicted: 56.38
# Actual: 54.0, Predicted: 53.04
# Actual: 75.0, Predicted: 75.05
# Actual: 40.0, Predicted: 42.07
# Actual: 61.0, Predicted: 60.59
# Actual: 67.0, Predicted: 66.84
# Actual: 72.0, Predicted: 74.11
# Actual: 42.0, Predicted: 41.41
# Actual: 60.0, Predicted: 64.61
# Actual: 41.0, Predicted: 44.31
# Actual: 32.0, Predicted: 29.37
# Actual: 53.0, Predicted: 52.50
# Actual: 42.0, Predicted: 39.27
# Actual: 49.0, Predicted: 48.83
# Actual: 56.0, Predicted: 55.79
# Actual: 24.0, Predicted: 24.63
# Actual: 39.0, Predicted: 41.86
# Actual: 61.0, Predicted: 60.18
# Actual: 78.0, Predicted: 79.26
# Actual: 53.0, Predicted: 52.85
# Actual: 48.0, Predicted: 50.03
# Actual: 54.0, Predicted: 52.66
# Actual: 70.0, Predicted: 69.06
# Actual: 59.0, Predicted: 55.81
# Actual: 89.0, Predicted: 86.87
# Actual: 58.0, Predicted: 58.24
# Actual: 52.0, Predicted: 49.52
# Actual: 32.0, Predicted: 31.41
# Actual: 32.0, Predicted: 36.66
# Actual: 69.0, Predicted: 70.17
# Actual: 40.0, Predicted: 40.45
# Actual: 73.0, Predicted: 70.10
# Actual: 39.0, Predicted: 39.47
# Actual: 40.0, Predicted: 41.91
# Actual: 35.0, Predicted: 38.63
# Actual: 52.0, Predicted: 48.46
# Actual: 77.0, Predicted: 73.53
# Actual: 67.0, Predicted: 68.83
# Actual: 58.0, Predicted: 60.99
# Actual: 66.0, Predicted: 64.37
# Actual: 66.0, Predicted: 62.74
# Actual: 62.0, Predicted: 64.09
# Actual: 66.0, Predicted: 65.68
# Actual: 49.0, Predicted: 47.40
# Actual: 32.0, Predicted: 34.33
# Actual: 32.0, Predicted: 33.35
# Actual: 38.0, Predicted: 39.10
# Actual: 16.0, Predicted: 18.94
# Actual: 35.0, Predicted: 29.83
# Actual: 49.0, Predicted: 47.27
# Actual: 29.0, Predicted: 29.60
# Actual: 34.0, Predicted: 33.45
# Actual: 33.0, Predicted: 36.67
# Actual: 73.0, Predicted: 72.79
# Actual: 23.0, Predicted: 22.15
# Actual: 35.0, Predicted: 36.73
# Actual: 30.0, Predicted: 30.73
# Actual: 73.0, Predicted: 75.00
# Actual: 43.0, Predicted: 40.40
# Actual: 38.0, Predicted: 35.78
# Actual: 21.0, Predicted: 20.86
# Actual: 26.0, Predicted: 25.99
# Actual: 43.0, Predicted: 46.39
# Actual: 32.0, Predicted: 33.31
# Actual: 64.0, Predicted: 64.74
# Actual: 20.0, Predicted: 21.64
# Actual: 41.0, Predicted: 40.30
# Actual: 70.0, Predicted: 73.14
# Actual: 36.0, Predicted: 38.59
# Actual: 26.0, Predicted: 27.35
# Actual: 37.0, Predicted: 40.36
# Actual: 89.0, Predicted: 86.57
# Actual: 77.0, Predicted: 74.81
# Actual: 47.0, Predicted: 50.23
# Actual: 33.0, Predicted: 32.53
# Actual: 61.0, Predicted: 61.05
# Actual: 39.0, Predicted: 39.57
# Actual: 74.0, Predicted: 72.69
# Actual: 54.0, Predicted: 58.41
# Actual: 47.0, Predicted: 44.55
# Actual: 49.0, Predicted: 47.70
# Actual: 53.0, Predicted: 50.62
# Actual: 66.0, Predicted: 70.27
# Actual: 84.0, Predicted: 83.17
# Actual: 27.0, Predicted: 25.85
# Actual: 23.0, Predicted: 22.50
# Actual: 72.0, Predicted: 69.86
# Actual: 16.0, Predicted: 16.20
# Actual: 47.0, Predicted: 50.88
# Actual: 73.0, Predicted: 70.73
# Actual: 45.0, Predicted: 46.00
# Actual: 68.0, Predicted: 67.73
# Actual: 69.0, Predicted: 65.97
# Actual: 69.0, Predicted: 67.90
# Actual: 69.0, Predicted: 69.49
# Actual: 65.0, Predicted: 67.62
# Actual: 48.0, Predicted: 51.65
# Actual: 57.0, Predicted: 59.17
# Actual: 62.0, Predicted: 62.21
# Actual: 70.0, Predicted: 65.36
# Actual: 73.0, Predicted: 73.07
# Actual: 39.0, Predicted: 38.94
# Actual: 53.0, Predicted: 51.42
# Actual: 40.0, Predicted: 40.62
# Actual: 47.0, Predicted: 44.59
# Actual: 68.0, Predicted: 68.81
# Actual: 73.0, Predicted: 70.82
# Actual: 23.0, Predicted: 21.98
# Actual: 39.0, Predicted: 39.80
# Actual: 40.0, Predicted: 41.99
# Actual: 42.0, Predicted: 39.34
# Actual: 35.0, Predicted: 34.85
# Actual: 47.0, Predicted: 47.71
# Actual: 46.0, Predicted: 42.72
# Actual: 26.0, Predicted: 29.82
# Actual: 36.0, Predicted: 33.20
# Actual: 75.0, Predicted: 70.36
# Actual: 48.0, Predicted: 49.94
# Actual: 57.0, Predicted: 58.78
# Actual: 62.0, Predicted: 64.54
# Actual: 50.0, Predicted: 48.33
# Actual: 30.0, Predicted: 31.68
# Actual: 44.0, Predicted: 45.03
# Actual: 36.0, Predicted: 34.45
# Actual: 69.0, Predicted: 70.82
# Actual: 66.0, Predicted: 69.11
# Actual: 46.0, Predicted: 45.37
# Actual: 68.0, Predicted: 68.82
# Actual: 68.0, Predicted: 69.47
# Actual: 37.0, Predicted: 36.55
# Actual: 36.0, Predicted: 36.16
# Actual: 40.0, Predicted: 42.96
# Actual: 40.0, Predicted: 39.63
# Actual: 60.0, Predicted: 61.45
# Actual: 70.0, Predicted: 67.96
# Actual: 43.0, Predicted: 43.96
# Actual: 81.0, Predicted: 76.37
# Actual: 42.0, Predicted: 44.92
# Actual: 60.0, Predicted: 61.11
# Actual: 36.0, Predicted: 34.20
# Actual: 46.0, Predicted: 47.82
# Actual: 60.0, Predicted: 60.58
# Actual: 67.0, Predicted: 71.46
# Actual: 49.0, Predicted: 51.60
# Actual: 47.0, Predicted: 49.65
# Actual: 79.0, Predicted: 79.70
# Actual: 61.0, Predicted: 58.60
# Actual: 82.0, Predicted: 82.55
# Actual: 48.0, Predicted: 48.79
# Actual: 54.0, Predicted: 55.23
# Actual: 75.0, Predicted: 77.76
# Actual: 68.0, Predicted: 66.08
# Actual: 50.0, Predicted: 50.18
# Actual: 87.0, Predicted: 87.68
# Actual: 25.0, Predicted: 22.29
# Actual: 45.0, Predicted: 50.96
# Actual: 25.0, Predicted: 23.38
# Actual: 28.0, Predicted: 31.76
# Actual: 36.0, Predicted: 35.86
# Actual: 53.0, Predicted: 50.60
# Actual: 47.0, Predicted: 49.86
# Actual: 84.0, Predicted: 81.38
# Actual: 66.0, Predicted: 66.55
# Actual: 66.0, Predicted: 67.88
# Actual: 55.0, Predicted: 54.17
# Actual: 71.0, Predicted: 69.20
# Actual: 86.0, Predicted: 81.52
# Actual: 80.0, Predicted: 79.76
# Actual: 36.0, Predicted: 34.49
# Actual: 57.0, Predicted: 56.54
# Actual: 77.0, Predicted: 76.17
# Actual: 52.0, Predicted: 52.36
# Actual: 29.0, Predicted: 30.68
# Actual: 43.0, Predicted: 42.76
# Actual: 30.0, Predicted: 32.48
# Actual: 74.0, Predicted: 78.65
# Actual: 27.0, Predicted: 26.12
# Actual: 72.0, Predicted: 73.65
# Actual: 82.0, Predicted: 82.05
# Actual: 31.0, Predicted: 33.92
# Actual: 62.0, Predicted: 59.84
# Actual: 79.0, Predicted: 85.06
# Actual: 92.0, Predicted: 90.76
# Actual: 27.0, Predicted: 25.82
# Actual: 79.0, Predicted: 79.01
# Actual: 82.0, Predicted: 79.90
# Actual: 28.0, Predicted: 30.36
# Actual: 73.0, Predicted: 68.67
# Actual: 59.0, Predicted: 61.05
# Actual: 81.0, Predicted: 79.25
# Actual: 59.0, Predicted: 55.27
# Actual: 77.0, Predicted: 77.48
# Actual: 26.0, Predicted: 27.83
# Actual: 70.0, Predicted: 68.03
# Actual: 38.0, Predicted: 39.20
# Actual: 42.0, Predicted: 44.30
# Actual: 40.0, Predicted: 38.97
# Actual: 35.0, Predicted: 33.10
# Actual: 56.0, Predicted: 55.41
# Actual: 48.0, Predicted: 48.16
# Actual: 76.0, Predicted: 75.79
# Actual: 71.0, Predicted: 71.40
# Actual: 20.0, Predicted: 21.42
# Actual: 75.0, Predicted: 77.66
# Actual: 89.0, Predicted: 90.18
# Actual: 79.0, Predicted: 79.02
# Actual: 40.0, Predicted: 35.27
# Actual: 57.0, Predicted: 59.74
# Actual: 66.0, Predicted: 66.52
# Actual: 69.0, Predicted: 71.85
# Actual: 85.0, Predicted: 88.54
# Actual: 53.0, Predicted: 50.08
# Actual: 37.0, Predicted: 36.11
# Actual: 58.0, Predicted: 54.78
# Actual: 71.0, Predicted: 73.76
# Actual: 42.0, Predicted: 41.23
# Actual: 58.0, Predicted: 53.70
# Actual: 68.0, Predicted: 65.75
# Actual: 56.0, Predicted: 54.56
# Actual: 52.0, Predicted: 54.15
# Actual: 54.0, Predicted: 51.11
# Actual: 66.0, Predicted: 67.47
# Actual: 48.0, Predicted: 47.21
# Actual: 69.0, Predicted: 70.76
# Actual: 62.0, Predicted: 62.60
# Actual: 80.0, Predicted: 77.54
# Actual: 71.0, Predicted: 69.48
# Actual: 82.0, Predicted: 81.77
# Actual: 56.0, Predicted: 51.57
# Actual: 53.0, Predicted: 53.82
# Actual: 72.0, Predicted: 70.01
# Actual: 76.0, Predicted: 76.60
# Actual: 63.0, Predicted: 65.54
# Actual: 70.0, Predicted: 70.66
# Actual: 59.0, Predicted: 62.29
# Actual: 42.0, Predicted: 42.42
# Actual: 67.0, Predicted: 66.14
# Actual: 52.0, Predicted: 50.49
# Actual: 40.0, Predicted: 40.00
# Actual: 50.0, Predicted: 50.35
# Actual: 79.0, Predicted: 78.99
# Actual: 75.0, Predicted: 72.32
# Actual: 63.0, Predicted: 61.19
# Actual: 56.0, Predicted: 53.26
# Actual: 40.0, Predicted: 44.86
# Actual: 57.0, Predicted: 54.05
# Actual: 50.0, Predicted: 48.46
# Actual: 39.0, Predicted: 35.15
# Actual: 36.0, Predicted: 37.53
# Actual: 59.0, Predicted: 59.79
# Actual: 49.0, Predicted: 49.40
# Actual: 26.0, Predicted: 31.17
# Actual: 28.0, Predicted: 33.72
# Actual: 88.0, Predicted: 86.58
# Actual: 17.0, Predicted: 19.26
# Actual: 81.0, Predicted: 83.94
# Actual: 63.0, Predicted: 61.48
# Actual: 74.0, Predicted: 77.66
# Actual: 32.0, Predicted: 30.76
# Actual: 72.0, Predicted: 73.18
# Actual: 91.0, Predicted: 92.95
# Actual: 44.0, Predicted: 43.73
# Actual: 66.0, Predicted: 68.97
# Actual: 45.0, Predicted: 42.20
# Actual: 68.0, Predicted: 68.49
# Actual: 71.0, Predicted: 71.58
# Actual: 59.0, Predicted: 58.09
# Actual: 56.0, Predicted: 53.34
# Actual: 78.0, Predicted: 78.84
# Actual: 81.0, Predicted: 79.49
# Actual: 74.0, Predicted: 72.27
# Actual: 65.0, Predicted: 62.01
# Actual: 65.0, Predicted: 65.67
# Actual: 40.0, Predicted: 38.49
# Actual: 49.0, Predicted: 48.01
# Actual: 54.0, Predicted: 52.77
# Actual: 48.0, Predicted: 52.87
# Actual: 40.0, Predicted: 38.05
# Actual: 90.0, Predicted: 87.42
# Actual: 36.0, Predicted: 35.28
# Actual: 89.0, Predicted: 90.05
# Actual: 78.0, Predicted: 74.63
# Actual: 69.0, Predicted: 69.54
# Actual: 75.0, Predicted: 74.38
# Actual: 58.0, Predicted: 60.57
# Actual: 44.0, Predicted: 44.83
# Actual: 74.0, Predicted: 74.46
# Actual: 75.0, Predicted: 76.62
# Actual: 69.0, Predicted: 70.80
# Actual: 34.0, Predicted: 33.44
# Actual: 38.0, Predicted: 35.32
# Actual: 58.0, Predicted: 60.66
# Actual: 92.0, Predicted: 86.99
# Actual: 84.0, Predicted: 84.73
# Actual: 62.0, Predicted: 63.95
# Actual: 59.0, Predicted: 55.71
# Actual: 62.0, Predicted: 60.26
# Actual: 75.0, Predicted: 73.14
# Actual: 59.0, Predicted: 60.82
# Actual: 52.0, Predicted: 50.25
# Actual: 69.0, Predicted: 63.95
# Actual: 67.0, Predicted: 69.06
# Actual: 65.0, Predicted: 62.39
# Actual: 70.0, Predicted: 71.90
# Actual: 12.0, Predicted: 14.64
# Actual: 86.0, Predicted: 86.36
# Actual: 73.0, Predicted: 73.21
# Actual: 41.0, Predicted: 41.32
# Actual: 55.0, Predicted: 55.23
# Actual: 62.0, Predicted: 58.07
# Actual: 61.0, Predicted: 56.89
# Actual: 33.0, Predicted: 32.89
# Actual: 77.0, Predicted: 76.94
# Actual: 63.0, Predicted: 60.39
# Actual: 91.0, Predicted: 90.26
# Actual: 82.0, Predicted: 80.75
# Actual: 72.0, Predicted: 67.76
# Actual: 20.0, Predicted: 22.66
# Actual: 20.0, Predicted: 20.64
# Actual: 46.0, Predicted: 45.84
# Actual: 44.0, Predicted: 42.52
# Actual: 79.0, Predicted: 81.74
# Actual: 34.0, Predicted: 32.67
# Actual: 92.0, Predicted: 92.35
# Actual: 25.0, Predicted: 23.81
# Actual: 69.0, Predicted: 69.52
# Actual: 20.0, Predicted: 21.85
# Actual: 27.0, Predicted: 25.62
# Actual: 40.0, Predicted: 39.15
# Actual: 83.0, Predicted: 83.74
# Actual: 50.0, Predicted: 50.23
# Actual: 55.0, Predicted: 56.17
# Actual: 39.0, Predicted: 34.20
# Actual: 23.0, Predicted: 21.77
# Actual: 58.0, Predicted: 56.67
# Actual: 74.0, Predicted: 73.16
# Actual: 95.0, Predicted: 93.68
# Actual: 64.0, Predicted: 64.70

# %%
import random

def load_csv(filename):
    data = []
    with open(filename, 'r') as f:
        lines = f.readlines()
        headers = lines[0].strip().split(',')

        # Columns to exclude (drop non-numeric or irrelevant)
        exclude_cols = ['Risk_MM', 'RainTomorrow', 'Date', 'Location',
                        'WindGustDir', 'WindDir9am', 'WindDir3pm']
        exclude_indices = [headers.index(col) for col in exclude_cols if col in headers]
        target_index = headers.index('RainTomorrow')

        for line in lines[1:]:
            values = line.strip().split(',')

            # Skip if target missing or invalid
            target_val = values[target_index]
            if target_val not in ['Yes', 'No']:
                continue

            row = []

            skip = False
            for i, val in enumerate(values):
                if i in exclude_indices:
                    continue
                if val == '':
                    skip = True
                    break
                try:
                    row.append(float(val))
                except ValueError:
                    skip = True
                    break

            if skip:
                continue

            # Add bias term 1.0 for intercept
            row.insert(0, 1.0)

            # Append label as float
            label = 1.0 if target_val == 'Yes' else 0.0
            row.append(label)
            data.append(row)
    return data

def sigmoid(z):
    import math
    return 1 / (1 + math.exp(-z))

def predict(features, weights):
    z = sum(w * x for w, x in zip(weights, features))
    return sigmoid(z)

def train_logistic_regression(data, lr=0.01, epochs=1000):
    num_features = len(data[0]) - 1
    weights = [0.0] * num_features

    for epoch in range(epochs):
        for row in data:
            features = row[:-1]
            label = row[-1]
            pred = predict(features, weights)
            error = label - pred
            for i in range(num_features):
                weights[i] += lr * error * features[i]
    return weights

def evaluate(data, weights):
    correct = 0
    total = 0
    for row in data:
        features = row[:-1]
        label = row[-1]
        prediction = predict(features, weights)
        predicted_class = 1.0 if prediction >= 0.5 else 0.0
        if predicted_class == label:
            correct += 1
        total += 1
    return correct / total if total > 0 else 0

if __name__ == "__main__":
    path = "/content/weatherAUS.csv"
    data = load_csv(path)

    if not data:
        print("No data loaded. Please check your CSV content.")
    else:
        # Proper random shuffle
        random.shuffle(data)

        # 80-20 train-test split
        split_index = int(0.8 * len(data))
        train_data = data[:split_index]
        test_data = data[split_index:]

        # Train and evaluate
        weights = train_logistic_regression(train_data, lr=0.01, epochs=1000)
        accuracy = evaluate(test_data, weights)
        print("Model Accuracy:", round(accuracy * 100, 2), "%")
# Out:
# No data loaded. Please check your CSV content.
